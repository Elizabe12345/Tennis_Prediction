# %%
import numpy as np
import pandas as pd
import os

# %%
# 定义基础路径和文件名模板
base_path = os.path.join("..", "dataset", "tour_level")
file_template = "atp_matches_{year}.csv"

# 存储所有 DataFrame 的列表
dfs = []

# 循环读取 2000-2024 年的文件
for year in range(2000, 2025):  # range不包含上限，实际是 2000-2024
    file_path = os.path.join(base_path, file_template.format(year=year))
    
    # 检查文件是否存在
    if os.path.exists(file_path):
        try:
            # 读取 CSV 文件
            df = pd.read_csv(file_path, encoding='utf-8')  # 如果编码报错可尝试 latin-1
            dfs.append(df)
            print(f"成功读取 {year} 年数据，行数: {len(df)}")
        except Exception as e:
            print(f"读取 {year} 年数据失败: {str(e)}")
    else:
        print(f"文件 {file_path} 不存在，已跳过")

# 纵向拼接所有 DataFrame
if dfs:
    combined_df = pd.concat(dfs, axis=0, ignore_index=True)
    print("\n合并完成！")
    print(f"总行数: {len(combined_df)}")
    print(f"总列数: {combined_df.shape[1]}")
else:
    print("未找到任何可合并的数据文件")
# Out:
# 成功读取 2000 年数据，行数: 3378
# 成功读取 2001 年数据，行数: 3307
# 成功读取 2002 年数据，行数: 3213
# 成功读取 2003 年数据，行数: 3218
# 成功读取 2004 年数据，行数: 3288
# 成功读取 2005 年数据，行数: 3264
# 成功读取 2006 年数据，行数: 3267
# 成功读取 2007 年数据，行数: 3192
# 成功读取 2008 年数据，行数: 3123
# 成功读取 2009 年数据，行数: 3085
# 成功读取 2010 年数据，行数: 3030
# 成功读取 2011 年数据，行数: 3015
# 成功读取 2012 年数据，行数: 3009
# 成功读取 2013 年数据，行数: 2944
# 成功读取 2014 年数据，行数: 2901
# 成功读取 2015 年数据，行数: 2943
# 成功读取 2016 年数据，行数: 2941
# 成功读取 2017 年数据，行数: 2911
# 成功读取 2018 年数据，行数: 2897
# 成功读取 2019 年数据，行数: 2806
# 成功读取 2020 年数据，行数: 1462
# 成功读取 2021 年数据，行数: 2733
# 成功读取 2022 年数据，行数: 2917
# 成功读取 2023 年数据，行数: 2986
# 成功读取 2024 年数据，行数: 3076
#
# 合并完成！
# 总行数: 74906
# 总列数: 49

# %%
for key, years in time_ranges.items():
    dfs = []  # 存储当前时间段的所有 DataFrame
    for year in years:
        file_path = os.path.join(directory, f"atp_matches_{year}.csv")
        if os.path.exists(file_path):
            df = pd.read_csv(file_path, encoding="utf-8")  # 读取 CSV
            
            # 转换 tourney_date 列为日期格式
            if "tourney_date" in df.columns:
                df["tourney_date"] = pd.to_datetime(df["tourney_date"], format="%Y%m%d").dt.date
            
            dfs.append(df)  # 添加到列表

    # 合并当前时间段的数据
    if dfs:
        dataframes[key] = pd.concat(dfs, ignore_index=True)
        print(f"{key} 合并完成，包含 {dataframes[key].shape[0]} 行，{dataframes[key].shape[1]} 列")
    else:
        print(f"{key} 没有找到任何数据")
# Out:
# df_00_04 合并完成，包含 16404 行，49 列
# df_05_09 合并完成，包含 15931 行，49 列
# df_10_14 合并完成，包含 14899 行，49 列
# df_15_19 合并完成，包含 14498 行，49 列
# df_20_24 合并完成，包含 13174 行，49 列

# %%
print(dfs)
# Out:
# [     tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0     2020-8888      Atp Cup    Hard         24             A   2020-01-06
# 1     2020-8888      Atp Cup    Hard         24             A   2020-01-06
# 2     2020-8888      Atp Cup    Hard         24             A   2020-01-06
# 3     2020-8888      Atp Cup    Hard         24             A   2020-01-06
# 4     2020-8888      Atp Cup    Hard         24             A   2020-01-06
# ...         ...          ...     ...        ...           ...          ...
# 1457  2020-7485      Antwerp    Hard         32             A   2020-10-19
# 1458  2020-7485      Antwerp    Hard         32             A   2020-10-19
# 1459  2020-7485      Antwerp    Hard         32             A   2020-10-19
# 1460  2020-7485      Antwerp    Hard         32             A   2020-10-19
# 1461  2020-7485      Antwerp    Hard         32             A   2020-10-19
#
#       match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0           300     104925          NaN          NaN  ...    51.0     39.0
# 1           299     105138          NaN          NaN  ...    35.0     21.0
# 2           298     104925          NaN          NaN  ...    57.0     35.0
# 3           297     105583          NaN          NaN  ...    54.0     39.0
# 4           296     104745          NaN          NaN  ...    55.0     37.0
# ...         ...        ...          ...          ...  ...     ...      ...
# 1457        125     105554          NaN          NaN  ...    43.0     31.0
# 1458        126     200267          NaN           WC  ...    45.0     27.0
# 1459        128     126203          7.0          NaN  ...    37.0     30.0
# 1460        129     144750          NaN            Q  ...    45.0     29.0
# 1461        130     200005          NaN          NaN  ...    32.0     26.0
#
#       l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0          6.0    10.0        6.0        8.0          2.0             9055.0
# 1          6.0     9.0        5.0       10.0         10.0             2335.0
# 2         25.0    14.0        6.0       11.0          2.0             9055.0
# 3         14.0    12.0        0.0        1.0         34.0             1251.0
# 4         10.0    14.0        1.0        5.0          1.0             9985.0
# ...        ...     ...        ...        ...          ...                ...
# 1457      14.0    13.0        3.0        7.0         35.0             1384.0
# 1458      10.0    12.0        4.0        9.0        528.0               58.0
# 1459       5.0     9.0        3.0        5.0         28.0             1670.0
# 1460       5.0    10.0        7.0       11.0         90.0              748.0
# 1461       7.0     9.0        2.0        4.0         38.0             1306.0
#
#      loser_rank loser_rank_points
# 0           1.0            9985.0
# 1          34.0            1251.0
# 2           5.0            5705.0
# 3          17.0            1840.0
# 4          18.0            1775.0
# ...         ...               ...
# 1457       79.0             802.0
# 1458       45.0            1165.0
# 1459       33.0            1402.0
# 1460       74.0             838.0
# 1461      172.0             353.0
#
# [1462 rows x 49 columns],      tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 0     2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 1     2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 2     2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 3     2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# 4     2021-0096  Tokyo Olympics    Hard         64             A   2021-07-24
# ...         ...             ...     ...        ...           ...          ...
# 2728  2021-9210       Laver Cup    Hard          8             A   2021-09-24
# 2729  2021-9210       Laver Cup    Hard          8             A   2021-09-24
# 2730  2021-9210       Laver Cup    Hard          8             A   2021-09-24
# 2731  2021-9210       Laver Cup    Hard          8             A   2021-09-24
# 2732  2021-9210       Laver Cup    Hard          8             A   2021-09-24
#
#       match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0           237     126207          NaN          NaN  ...     NaN      NaN
# 1           238     105526          NaN          NaN  ...     NaN      NaN
# 2           239     111576          NaN          NaN  ...     NaN      NaN
# 3           240     105357          NaN          NaN  ...     NaN      NaN
# 4           241     207830          NaN          NaN  ...     NaN      NaN
# ...         ...        ...          ...          ...  ...     ...      ...
# 2728        102     126610          NaN          NaN  ...     NaN      NaN
# 2729        103     106421          NaN          NaN  ...     NaN      NaN
# 2730        104     126094          NaN          NaN  ...     NaN      NaN
# 2731        105     100644          NaN          NaN  ...     NaN      NaN
# 2732        106     134770          NaN          NaN  ...     NaN      NaN
#
#       l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0          NaN     NaN        NaN        NaN         53.0             1228.0
# 1          NaN     NaN        NaN        NaN         48.0             1410.0
# 2          NaN     NaN        NaN        NaN        160.0              471.0
# 3          NaN     NaN        NaN        NaN         44.0             1476.0
# 4          NaN     NaN        NaN        NaN        145.0              525.0
# ...        ...     ...        ...        ...          ...                ...
# 2728       NaN     NaN        NaN        NaN          7.0             5173.0
# 2729       NaN     NaN        NaN        NaN          2.0            10575.0
# 2730       NaN     NaN        NaN        NaN          5.0             6130.0
# 2731       NaN     NaN        NaN        NaN          4.0             7760.0
# 2732       NaN     NaN        NaN        NaN         10.0             3440.0
#
#      loser_rank loser_rank_points
# 0          71.0             996.0
# 1          95.0             829.0
# 2         197.0             354.0
# 3          61.0            1106.0
# 4         137.0             570.0
# ...         ...               ...
# 2728       11.0            3368.0
# 2729       12.0            3310.0
# 2730       15.0            2800.0
# 2731       22.0            2171.0
# 2732       19.0            2341.0
#
# [2733 rows x 49 columns],                             tourney_id                  tourney_name surface  \
# 0                            2022-8888                       Atp Cup    Hard
# 1                            2022-8888                       Atp Cup    Hard
# 2                            2022-8888                       Atp Cup    Hard
# 3                            2022-8888                       Atp Cup    Hard
# 4                            2022-8888                       Atp Cup    Hard
# ...                                ...                           ...     ...
# 2912  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2913  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2914  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2915  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2916  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
#       draw_size tourney_level tourney_date  match_num  winner_id  winner_seed  \
# 0            16             A   2022-01-03        300     200000          NaN
# 1            16             A   2022-01-03        299     133430          NaN
# 2            16             A   2022-01-03        298     105138          NaN
# 3            16             A   2022-01-03        297     105807          NaN
# 4            16             A   2022-01-03        296     106421          NaN
# ...         ...           ...          ...        ...        ...          ...
# 2912          4             D   2022-03-04          4     209362          NaN
# 2913          4             D   2022-03-04          5     202065          NaN
# 2914          4             D   2022-03-04          1     138846          NaN
# 2915          4             D   2022-03-04          2     209409          NaN
# 2916          4             D   2022-03-04          4     208414          NaN
#
#      winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  l_bpSaved  \
# 0             NaN  ...    50.0     32.0       7.0    10.0        3.0
# 1             NaN  ...    33.0     21.0       8.0     9.0        3.0
# 2             NaN  ...    80.0     62.0      20.0    16.0        6.0
# 3             NaN  ...    27.0     17.0       1.0     7.0        4.0
# 4             NaN  ...    35.0     22.0       4.0     8.0        3.0
# ...           ...  ...     ...      ...       ...     ...        ...
# 2912          NaN  ...    68.0     42.0      12.0    10.0       11.0
# 2913          NaN  ...    56.0     40.0      20.0    15.0        4.0
# 2914          NaN  ...    54.0     29.0       8.0    11.0        6.0
# 2915          NaN  ...    39.0     24.0       7.0    10.0        5.0
# 2916          NaN  ...    34.0     24.0      13.0    10.0        5.0
#
#       l_bpFaced  winner_rank winner_rank_points loser_rank loser_rank_points
# 0           5.0         11.0             3308.0       19.0            2260.0
# 1           6.0         14.0             2475.0       20.0            2230.0
# 2           7.0         19.0             2260.0        9.0            3706.0
# 3           8.0         20.0             2230.0      860.0              18.0
# 4           7.0          2.0             8640.0       11.0            3308.0
# ...         ...          ...                ...        ...               ...
# 2912       13.0       1103.0                9.0     1130.0               8.0
# 2913        8.0        808.0               23.0     1390.0               4.0
# 2914       10.0       1059.0               10.0     1881.0               1.0
# 2915        9.0       1050.0               10.0        NaN               NaN
# 2916        8.0          NaN                NaN        NaN               NaN
#
# [2917 rows x 49 columns],                             tourney_id                  tourney_name surface  \
# 0                            2023-9900                    United Cup    Hard
# 1                            2023-9900                    United Cup    Hard
# 2                            2023-9900                    United Cup    Hard
# 3                            2023-9900                    United Cup    Hard
# 4                            2023-9900                    United Cup    Hard
# ...                                ...                           ...     ...
# 2981  2023-M-DC-2023-WG2-PO-RSA-LUX-01  Davis Cup WG2 PO: RSA vs LUX     NaN
# 2982  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 2983  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 2984  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
# 2985  2023-M-DC-2023-WG2-PO-TUN-CYP-01  Davis Cup WG2 PO: TUN vs CYP     NaN
#
#       draw_size tourney_level tourney_date  match_num  winner_id  winner_seed  \
# 0            18             A   2023-01-02        300     126203          3.0
# 1            18             A   2023-01-02        299     126207          NaN
# 2            18             A   2023-01-02        296     126203          3.0
# 3            18             A   2023-01-02        295     126207          NaN
# 4            18             A   2023-01-02        292     126774          1.0
# ...         ...           ...          ...        ...        ...          ...
# 2981          4             D   2023-02-04          5     202335          NaN
# 2982          4             D   2023-02-03          1     117365          NaN
# 2983          4             D   2023-02-03          2     121411          NaN
# 2984          4             D   2023-02-03          4     144949          NaN
# 2985          4             D   2023-02-03          5     121411          NaN
#
#      winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  l_bpSaved  \
# 0             NaN  ...    62.0     47.0      15.0    12.0        9.0
# 1             NaN  ...    12.0      8.0       3.0     4.0        1.0
# 2             NaN  ...    62.0     51.0       7.0    12.0        2.0
# 3             NaN  ...    41.0     26.0      12.0     9.0        6.0
# 4             NaN  ...    58.0     48.0      18.0    16.0        1.0
# ...           ...  ...     ...      ...       ...     ...        ...
# 2981          NaN  ...     NaN      NaN       NaN     NaN        NaN
# 2982          NaN  ...     NaN      NaN       NaN     NaN        NaN
# 2983          NaN  ...     NaN      NaN       NaN     NaN        NaN
# 2984          NaN  ...     NaN      NaN       NaN     NaN        NaN
# 2985          NaN  ...     NaN      NaN       NaN     NaN        NaN
#
#       l_bpFaced  winner_rank winner_rank_points loser_rank loser_rank_points
# 0           9.0          9.0             3355.0       16.0            2375.0
# 1           3.0         19.0             2000.0       23.0            1865.0
# 2           2.0          9.0             3355.0       10.0            2905.0
# 3           9.0         19.0             2000.0      245.0             220.0
# 4           2.0          4.0             5550.0       16.0            2375.0
# ...         ...          ...                ...        ...               ...
# 2981        NaN          NaN                NaN     1717.0               1.0
# 2982        NaN        990.0               11.0      279.0             190.0
# 2983        NaN        364.0              131.0      894.0              15.0
# 2984        NaN        894.0               15.0      285.0             184.0
# 2985        NaN        364.0              131.0      990.0              11.0
#
# [2986 rows x 49 columns],                             tourney_id                  tourney_name surface  \
# 0                            2024-0339                      Brisbane    Hard
# 1                            2024-0339                      Brisbane    Hard
# 2                            2024-0339                      Brisbane    Hard
# 3                            2024-0339                      Brisbane    Hard
# 4                            2024-0339                      Brisbane    Hard
# ...                                ...                           ...     ...
# 3071  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 3072  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3073  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3074  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3075  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
#       draw_size tourney_level tourney_date  match_num  winner_id  winner_seed  \
# 0            32             A   2024-01-01        300     105777          2.0
# 1            32             A   2024-01-01        299     208029          1.0
# 2            32             A   2024-01-01        298     105777          2.0
# 3            32             A   2024-01-01        297     208029          1.0
# 4            32             A   2024-01-01        296     126128          NaN
# ...         ...           ...          ...        ...        ...          ...
# 3071          4             D   2024-02-03          5     212051          NaN
# 3072          4             D   2024-02-02          1     122533          NaN
# 3073          4             D   2024-02-02          2     144748          NaN
# 3074          4             D   2024-02-02          4     122533          NaN
# 3075          4             D   2024-02-02          5     202475          NaN
#
#      winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  l_bpSaved  \
# 0             NaN  ...    58.0     44.0      16.0    11.0        8.0
# 1             NaN  ...    35.0     31.0      10.0    11.0        5.0
# 2             NaN  ...    39.0     24.0      14.0    10.0        5.0
# 3             NaN  ...    51.0     31.0      16.0    10.0        3.0
# 4             NaN  ...    37.0     27.0      16.0    10.0        5.0
# ...           ...  ...     ...      ...       ...     ...        ...
# 3071          NaN  ...    30.0     17.0       7.0     6.0        8.0
# 3072          NaN  ...    41.0     25.0       6.0     9.0        1.0
# 3073          NaN  ...    51.0     25.0       7.0    11.0        5.0
# 3074          NaN  ...    51.0     32.0      17.0    14.0        5.0
# 3075          NaN  ...    53.0     25.0       8.0     8.0        9.0
#
#       l_bpFaced  winner_rank winner_rank_points loser_rank loser_rank_points
# 0           9.0         14.0             2570.0        8.0            3660.0
# 1           7.0          8.0             3660.0       39.0            1122.0
# 2           7.0         14.0             2570.0       55.0             902.0
# 3           5.0          8.0             3660.0      116.0             573.0
# 4           8.0         39.0             1122.0       44.0            1021.0
# ...         ...          ...                ...        ...               ...
# 3071       14.0       1109.0                8.0      740.0              34.0
# 3072        4.0        554.0               67.0      748.0              32.0
# 3073       12.0        416.0              109.0        NaN               NaN
# 3074        9.0        554.0               67.0      416.0             109.0
# 3075       14.0        748.0               32.0        NaN               NaN
#
# [3076 rows x 49 columns]]

# %%
print(dataframes["df_00_04"])
# Out:
#       tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0       2000-301     Auckland    Hard         32             A   2000-01-10
# 1       2000-301     Auckland    Hard         32             A   2000-01-10
# 2       2000-301     Auckland    Hard         32             A   2000-01-10
# 3       2000-301     Auckland    Hard         32             A   2000-01-10
# 4       2000-301     Auckland    Hard         32             A   2000-01-10
# ...          ...          ...     ...        ...           ...          ...
# 16399   2004-615   Dusseldorf    Clay         64             A   2004-05-17
# 16400   2004-615   Dusseldorf    Clay         64             A   2004-05-17
# 16401   2004-615   Dusseldorf    Clay         64             A   2004-05-17
# 16402   2004-615   Dusseldorf    Clay         64             A   2004-05-17
# 16403   2004-615   Dusseldorf    Clay         64             A   2004-05-17
#
#        match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0              1     103163          1.0          NaN  ...    55.0     39.0
# 1              2     102607          NaN            Q  ...    32.0     25.0
# 2              3     103252          NaN          NaN  ...    33.0     20.0
# 3              4     103507          7.0          NaN  ...    43.0     29.0
# 4              5     102103          NaN            Q  ...    46.0     34.0
# ...          ...        ...          ...          ...  ...     ...      ...
# 16399        290     103428          NaN          NaN  ...     NaN      NaN
# 16400        283     102783          NaN          NaN  ...     NaN      NaN
# 16401        282     103428          NaN          NaN  ...     NaN      NaN
# 16402        278     102610          NaN          NaN  ...     NaN      NaN
# 16403        275     102783          NaN          NaN  ...     NaN      NaN
#
#        l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0          29.0    17.0        4.0        7.0         11.0             1612.0
# 1          18.0    12.0        3.0        6.0        211.0              157.0
# 2           7.0     8.0        7.0       11.0         48.0              726.0
# 3          14.0    10.0        6.0        8.0         45.0              768.0
# 4          18.0    12.0        5.0        9.0        167.0              219.0
# ...         ...     ...        ...        ...          ...                ...
# 16399       NaN     NaN        NaN        NaN         23.0             1145.0
# 16400       NaN     NaN        NaN        NaN          7.0             2370.0
# 16401       NaN     NaN        NaN        NaN         23.0             1145.0
# 16402       NaN     NaN        NaN        NaN         27.0             1075.0
# 16403       NaN     NaN        NaN        NaN          7.0             2370.0
#
#       loser_rank loser_rank_points
# 0           63.0             595.0
# 1           49.0             723.0
# 2           59.0             649.0
# 3           61.0             616.0
# 4           34.0             873.0
# ...          ...               ...
# 16399       28.0            1070.0
# 16400       14.0            1425.0
# 16401       15.0            1420.0
# 16402      114.0             355.0
# 16403       24.0            1115.0
#
# [16404 rows x 49 columns]

# %%
for key, df in dataframes.items():
    print(f"\n{key} 缺失值统计:")
    
    # 统计每列缺失值的数量
    missing_values = df.isnull().sum()
    
    # 只显示缺失值数量大于 0 的列
    missing_values = missing_values[missing_values > 0]
    
    if not missing_values.empty:
        print(missing_values)
    else:
        print("  没有缺失值")
# Out:
# df_00_04 缺失值统计:
# winner_seed           10185
# winner_entry          14467
# winner_ht               504
# winner_age                2
# loser_seed            12908
# loser_entry           13216
# loser_ht                931
# minutes                1979
# w_ace                  1965
# w_df                   1965
# w_svpt                 1965
# w_1stIn                1965
# w_1stWon               1965
# w_2ndWon               1965
# w_SvGms                1965
# w_bpSaved              1965
# w_bpFaced              1965
# l_ace                  1965
# l_df                   1965
# l_svpt                 1965
# l_1stIn                1965
# l_1stWon               1965
# l_2ndWon               1965
# l_SvGms                1965
# l_bpSaved              1965
# l_bpFaced              1965
# winner_rank             202
# winner_rank_points      202
# loser_rank              452
# loser_rank_points       452
# dtype: int64
#
# df_05_09 缺失值统计:
# winner_seed            9196
# winner_entry          14030
# winner_ht               430
# loser_seed            12431
# loser_entry           12850
# loser_ht                878
# minutes                1812
# w_ace                  1813
# w_df                   1813
# w_svpt                 1813
# w_1stIn                1813
# w_1stWon               1813
# w_2ndWon               1813
# w_SvGms                1813
# w_bpSaved              1813
# w_bpFaced              1813
# l_ace                  1813
# l_df                   1813
# l_svpt                 1813
# l_1stIn                1813
# l_1stWon               1813
# l_2ndWon               1813
# l_SvGms                1813
# l_bpSaved              1813
# l_bpFaced              1813
# winner_rank             109
# winner_rank_points      109
# loser_rank              345
# loser_rank_points       345
# dtype: int64
#
# df_10_14 缺失值统计:
# winner_seed            8452
# winner_entry          13180
# winner_ht               314
# loser_seed            11459
# loser_entry           11927
# loser_ht                638
# minutes                1659
# w_ace                  1659
# w_df                   1659
# w_svpt                 1659
# w_1stIn                1659
# w_1stWon               1659
# w_2ndWon               1659
# w_SvGms                1659
# w_bpSaved              1659
# w_bpFaced              1659
# l_ace                  1659
# l_df                   1659
# l_svpt                 1659
# l_1stIn                1659
# l_1stWon               1659
# l_2ndWon               1659
# l_SvGms                1659
# l_bpSaved              1659
# l_bpFaced              1659
# winner_rank             123
# winner_rank_points      123
# loser_rank              316
# loser_rank_points       316
# dtype: int64
#
# df_15_19 缺失值统计:
# winner_seed            8286
# winner_entry          12577
# winner_ht               124
# winner_age                1
# loser_seed            10945
# loser_entry           11346
# loser_hand                4
# loser_ht                311
# minutes                1850
# w_ace                   536
# w_df                    536
# w_svpt                  536
# w_1stIn                 536
# w_1stWon                536
# w_2ndWon                536
# w_SvGms                 536
# w_bpSaved               536
# w_bpFaced               536
# l_ace                   536
# l_df                    536
# l_svpt                  536
# l_1stIn                 536
# l_1stWon                536
# l_2ndWon                536
# l_SvGms                 536
# l_bpSaved               536
# l_bpFaced               536
# winner_rank              75
# winner_rank_points       75
# loser_rank              205
# loser_rank_points       205
# dtype: int64
#
# df_20_24 缺失值统计:
# surface                  53
# winner_seed            7667
# winner_entry          11146
# winner_ht                53
# winner_age                2
# loser_seed             9925
# loser_entry           10145
# loser_ht                151
# loser_age                 3
# minutes                 874
# w_ace                   547
# w_df                    547
# w_svpt                  547
# w_1stIn                 547
# w_1stWon                547
# w_2ndWon                547
# w_SvGms                 547
# w_bpSaved               547
# w_bpFaced               547
# l_ace                   547
# l_df                    547
# l_svpt                  547
# l_1stIn                 547
# l_1stWon                547
# l_2ndWon                547
# l_SvGms                 547
# l_bpSaved               547
# l_bpFaced               547
# winner_rank              64
# winner_rank_points       64
# loser_rank              150
# loser_rank_points       150
# dtype: int64

# %%
# 存储所有时间段的赛事名称
tourney_names = set()

# 遍历所有 DataFrame，提取 tourney_name
for key, df in dataframes.items():
    if "tourney_name" in df.columns:
        tourney_names.update(df["tourney_name"].dropna().unique())

# 输出所有赛事名称
print(f"所有年份的赛事名称（共 {len(tourney_names)} 个）:")
print(tourney_names)
# Out:
# 所有年份的赛事名称（共 1962 个）:
# {'Davis Cup G2 R1: VIE vs INA', 'Davis Cup WG PO: GER vs RSA', 'Davis Cup G2 R1: PUR vs MEX', 'Davis Cup G1 PO: CHN vs THA', 'Davis Cup G1 QF: BLR vs RSA', 'Davis Cup WG1 PO: UZB vs TUR', 'Davis Cup WG PO: CAN vs BLR', 'Davis Cup Finals RR: GBR vs CZE', 'Davis Cup WG R1: PER vs ESP', 'Davis Cup G1 R2: AUT vs SVK', 'Davis Cup WG1 PO: VEN vs NZL', 'Davis Cup G2 PO: EGY vs GEO', 'Davis Cup WG R1: AUT vs RUS', 'Davis Cup G1 R2: JPN vs IND', 'Davis Cup G1 R1: JPN vs CHN', 'Davis Cup Finals RR: AUS vs HUN', 'Davis Cup G2 QF: PAR vs AHO', 'Davis Cup QLS R1: GER vs SUI', 'Davis Cup G2 R1: DEN vs CYP', 'Murray River Open', 'Davis Cup QLS R1: JPN vs ECU', "Queen's Club", 'Davis Cup WG SF: SVK vs ARG', 'Davis Cup G2 QF: HKG vs PAK', 'Davis Cup G2 R3: URU vs MEX', 'Davis Cup WG2 PO: POL vs HKG', 'Davis Cup WG2 PO: IRI vs EST', 'Davis Cup G1 QF: JPN vs THA', 'Davis Cup WG SF: ARG vs CZE', 'Davis Cup WG R1: AUT vs ARG', 'Davis Cup WG R1: BEL vs SUI', 'Davis Cup WG PO: COL vs USA', 'Davis Cup Finals RR: NED vs FIN', 'Davis Cup QLS R1: SUI vs RUS', 'Davis Cup G2 PO: MDA vs TUR', 'Davis Cup Finals RR: ESP vs RUS', 'Davis Cup WG1 PO: LTU vs GEO', 'Davis Cup G2 R1: MEX vs PAR', 'Davis Cup G1 PO: NOR vs FIN', 'Davis Cup G2 R2: KAZ vs NZL', 'Davis Cup WG PO: GBR vs AUT', 'Davis Cup G2 R1: IRL vs MAR', 'Davis Cup G2 PO: PHI vs HKG', 'Davis Cup G2 PO: YUG vs POL', 'Davis Cup G1 R2: MEX vs CAN', 'Nice', 'Davis Cup WG R1: GER vs ROU', 'Davis Cup Finals RR: CRO vs ESP', 'Davis Cup G1 R1: HUN vs UKR', 'Davis Cup G2 PO: IRI vs MAS', 'Davis Cup G1 R2: ISR vs ITA', 'Davis Cup WG1 PO: UZB vs POL', 'Davis Cup WG PO: ITA vs CHI', 'Davis Cup WG R1: AUS vs GBR', 'Davis Cup G2 R1: IRI vs INA', 'Davis Cup WG2 PO: CHN vs SLO', 'Davis Cup WG PO: AUS vs BEL', 'Davis Cup G1 R1: IND vs KOR', 'Davis Cup WG PO: JPN vs ISR', 'Davis Cup WG SF: FRA vs ESP', 'Davis Cup G1 PO: ZIM vs SLO', 'Davis Cup G2 R1: DOM vs BOL', 'Cologne 2', 'Davis Cup G1 PO: KOR vs CHN', 'Davis Cup G2 R1: MEX vs GUA', 'Davis Cup G1 R2: UZB vs KOR', 'Mallorca', 'Davis Cup G2 QF: ESA vs PAR', 'Davis Cup G2 PO: TJK vs IRI', 'Davis Cup WG PO: SUI vs ECU', 'Davis Cup G2 R3: THA vs NZL', 'Davis Cup G2 R2: NOR vs MKD', 'Davis Cup G2 PO: POL vs MON', 'Davis Cup WG QF: ESP vs CRO', 'Davis Cup QLS R1: GER vs BLR', 'Davis Cup QLS R1: KAZ vs POR', 'Davis Cup WG R1: CAN vs JPN', 'Davis Cup WG R1: AUS vs SWE', 'Davis Cup WG1 R1: ISR vs UKR', 'Davis Cup WG R1: ESP vs SUI', 'Davis Cup G2 SF: CRO vs CIV', 'Kuala Lumpur', 'Davis Cup G2 R2: KOR vs POC', 'Santiago', 'Davis Cup WG R1: BEL vs SRB', 'Davis Cup G1 R1: KOR vs KAZ', 'Davis Cup WG2 R1: RSA vs VEN', 'Davis Cup G1 SF: PER vs ECU', 'Davis Cup WG PO: ECU vs ROU', 'Davis Cup Finals RR: AUS vs CZE', 'Davis Cup WG QF: FRA vs CZE', 'Davis Cup G2 R1: PHI vs CHN', 'Davis Cup G2 R2: MEX vs BAR', 'Davis Cup QLS R1: SRB vs SVK', 'Davis Cup WG SF: FRA vs CZE', 'Cologne 1', 'Davis Cup G1 R2: ECU vs CAN', 'Davis Cup WG R1: GBR vs SWE', 'Davis Cup G2 R2: BLR vs BIH', 'Davis Cup G1 PO: ISR vs GRE', 'Davis Cup G1 PO: CAN vs DOM', 'Davis Cup G2 R1: LIB vs IRI', 'Davis Cup WG R1: JPN vs CRO', 'Davis Cup G1 PO: BLR vs POL', 'Davis Cup G1 R2: ISR vs GBR', 'Davis Cup Finals RR: AUS vs SUI', 'Belgrade 2', 'Indianapolis', 'Davis Cup G2 R1: TUR vs GRE', 'Davis Cup G2 R1: PAK vs HKG', 'Masters Cup', 'Davis Cup G2 R1: HKG vs TJK', 'Davis Cup G2 R1: KUW vs POC', 'Davis Cup WG1 PO: BUL vs BIH', 'Davis Cup G1 PO: LUX vs MAR', 'Davis Cup G2 PO: EGY vs DEN', 'Sardinia', 'Davis Cup WG PO: ESP vs IND', 'Davis Cup G1 R1: UKR vs SWE', 'Davis Cup Finals RR: CRO vs RUS', 'Davis Cup G2 R1: CHN vs PHI', 'Davis Cup WG QF: KAZ vs CZE', 'Davis Cup WG1 R1: JPN vs COL', 'Davis Cup WG SF: RUS vs ARG', 'Davis Cup G2 R1: NGR vs POL', 'Davis Cup G1 PO: BLR vs SVK', 'Davis Cup WG SF: GBR vs ARG', 'Davis Cup G2 R2: MON vs LAT', 'Davis Cup QLS R1: GBR vs COL', 'Davis Cup G1 PO: ECU vs PER', 'Davis Cup WG1 R1: AUT vs POR', 'Davis Cup G2 PO: JAM vs AHO', 'Davis Cup WG R1: CZE vs KAZ', 'Davis Cup QLS R1: CZE vs POR ...

# %%
target_tourneys = {"Laver Cup", "Tour Finals", "United Cup", "Next Gen Finals", "Atp Cup"}

# 存储筛选后的 DataFrame
filtered_dataframes = {}

for key, df in dataframes.items():
    if "tourney_name" in df.columns:
        filtered_df = df[df["tourney_name"].isin(target_tourneys)]
        filtered_dataframes[key] = filtered_df  # 存储筛选后的 DataFrame
        print(f"{key} 赛事筛选完成，共 {filtered_df.shape[0]} 条记录")

# 合并所有时间段的筛选结果
filtered_all = pd.concat(filtered_dataframes.values(), ignore_index=True)

# 输出筛选后的数据概览
print("\n所有年份筛选后赛事信息：")
print(filtered_all.head())
# Out:
# df_00_04 赛事筛选完成，共 0 条记录
# df_05_09 赛事筛选完成，共 15 条记录
# df_10_14 赛事筛选完成，共 75 条记录
# df_15_19 赛事筛选完成，共 101 条记录
# df_20_24 赛事筛选完成，共 356 条记录
#
# 所有年份筛选后赛事信息：
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2009-605  Tour Finals    Hard          8             F   2009-11-22
# 1   2009-605  Tour Finals    Hard          8             F   2009-11-22
# 2   2009-605  Tour Finals    Hard          8             F   2009-11-22
# 3   2009-605  Tour Finals    Hard          8             F   2009-11-22
# 4   2009-605  Tour Finals    Hard          8             F   2009-11-22
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0          1     103819          NaN          NaN  ...    66.0     43.0
# 1          2     103819          NaN          NaN  ...    46.0     33.0
# 2          3     105223          NaN          NaN  ...    51.0     40.0
# 3          4     103786          NaN          NaN  ...    50.0     41.0
# 4          5     105223          NaN          NaN  ...    73.0     45.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0      12.0    14.0        2.0        5.0          1.0            10150.0
# 1      21.0    13.0        8.0       13.0          1.0            10150.0
# 2      17.0    14.0        4.0        7.0          5.0             5985.0
# 3      11.0    15.0        1.0        5.0          7.0             3630.0
# 4      21.0    16.0        5.0        7.0          5.0             5985.0
#
#   loser_rank loser_rank_points
# 0        8.0            3300.0
# 1        4.0            6630.0
# 2        1.0           10150.0
# 3        1.0           10150.0
# 4        8.0            3300.0
#
# [5 rows x 49 columns]

# %% [markdown]
# 添加touney_ioc列

# %%
# 按 tourney_id 和 tourney_name 进行分组，统计每个赛事的比赛场次
grouped = filtered_all.groupby(["tourney_id", "tourney_name"]).size().reset_index(name="match_count")

# 输出分组统计结果
print("\n按 tourney_id 和 tourney_name 分组的比赛统计：")
print(grouped.head(50))
# Out:
# 按 tourney_id 和 tourney_name 分组的比赛统计：
#    tourney_id     tourney_name  match_count
# 0    2009-605      Tour Finals           15
# 1    2010-605      Tour Finals           15
# 2    2011-605      Tour Finals           15
# 3    2012-605      Tour Finals           15
# 4    2013-605      Tour Finals           15
# 5    2014-605      Tour Finals           15
# 6    2015-605      Tour Finals           15
# 7   2016-0605      Tour Finals           15
# 8   2017-0605      Tour Finals           15
# 9   2017-9210        Laver Cup            9
# 10  2018-0605      Tour Finals           15
# 11  2018-9210        Laver Cup            8
# 12  2019-0605      Tour Finals           15
# 13  2019-9210        Laver Cup            9
# 14  2020-0605      Tour Finals           15
# 15  2020-8888          Atp Cup           86
# 16  2021-0605      Tour Finals           15
# 17  2021-8888          Atp Cup           30
# 18  2021-9210        Laver Cup            6
# 19  2022-0605      Tour Finals           15
# 20  2022-8888          Atp Cup           54
# 21  2022-9210        Laver Cup            8
# 22  2023-0605      Tour Finals           15
# 23  2023-9900       United Cup           48
# 24  2024-0605      Tour Finals           15
# 25  2024-7696  Next Gen Finals           15
# 26  2024-9210        Laver Cup            9
# 27  2024-9900       United Cup           25

# %%
# 赛事名称对应的国家/地区代码字典
tennis_events_ioc = {
    'Hong Kong': 'CHN', 'Toulouse': 'FRA', 'New York': 'USA', 'Antalya': 'TUR', 'Tel Aviv': 'ISR',
    'Indianapolis': 'USA', 'London': 'GBR', 'Stockholm': 'SWE', 'Auckland': 'NZL', 
    'Cincinnati Masters': 'USA', 'Canada Masters': 'CAN', 'Atlanta': 'USA', 'Estoril': 'POR', 
    'San Marino': 'SMR', 'Barcelona': 'ESP', 'Istanbul': 'TUR', 'Madrid Masters': 'ESP', 
    'Munich': 'GER', 'Vienna': 'AUT', 'Warsaw': 'POL', 'Mumbai': 'IND', 'Shanghai': 'CHN', 
    'Rio de Janeiro': 'BRA', 'Sao Paulo': 'BRA', 'US Open': 'USA', 'Hamburg': 'GER', 
    'Sydney': 'AUS', 'Cordoba': 'ARG', 'Doha': 'QAT', 'Beijing': 'CHN', 'Mexico City': 'MEX', 
    'Ho Chi Minh City': 'VNM', 'Australian Open': 'AUS', 'Cologne 1': 'GER', 'Tokyo': 'JPN', 
    'Chennai': 'IND', 'Mallorca': 'ESP', 'Paris Olympics': 'FRA', 'Parma': 'ITA', 'Gstaad': 'SUI', 
    'Bastad': 'SWE', 'Budapest': 'HUN', 'Amersfoort': 'NED', 'Houston': 'USA', 'Long Island': 'USA', 
    'St. Petersburg': 'RUS', 'Montpellier': 'FRA', 'Nur-Sultan': 'KAZ', 'Kitzbuhel': 'AUT', 
    'Monte Carlo Masters': 'MON', 'Washington': 'USA', 'Bogota': 'COL', 'Gijon': 'ESP', 
    'Shanghai Masters': 'CHN', 'Newport': 'USA', 'Wimbledon': 'GBR', 'Zagreb': 'CRO', 
    'Miami Masters': 'USA', 'Adelaide 1': 'AUS', 'Shenzhen': 'CHN', 'Quito': 'ECU', 
    'Valencia': 'ESP', 'San Diego': 'USA', 'Eastbourne': 'GBR', 'Stuttgart Outdoor': 'GER', 
    'Marbella': 'ESP', 'Los Cabos': 'MEX', 'Florence': 'ITA', 'Brisbane': 'AUS', 'United Cup': 'AUS', 
    'Atp Cup': 'AUS', 'Tour Finals': 'ITA', 'Masters Cup': 'VAR', 'Rio Olympics': 'BRA', 
    'Tokyo Olympics': 'JPN', 'Athens Olympics': 'GRE', 'London Olympics': 'GBR', 'Chengdu': 'CHN', 
    'Cagliari': 'ITA', 'Casablanca': 'MAR', 'Copenhagen': 'DEN', 'Delray Beach': 'USA', 
    'Dusseldorf': 'GER', 'Las Vegas': 'USA', 'Lyon': 'FRA', 'Metz': 'FRA', 'Naples': 'ITA', 
    'Orlando': 'USA', 'Palermo': 'ITA', 'Pune': 'IND', 'Rotterdam': 'NED', 'Santiago': 'CHL', 
    'Seoul': 'KOR', 'St. Poelten': 'AUT', 'Stuttgart': 'GER', 'Tashkent': 'UZB', 'Umag': 'CRO', 
    'Vina del Mar': 'CHL', 'Winston-Salem': 'USA', 'Zhuhai': 'CHN', 's Hertogenbosch': 'NED', 
    "Queen's Club": 'GBR', 'Murray River Open': 'AUS', 'Great Ocean Road Open': 'AUS', 
    'NextGen Finals': 'KSA', 'Cologne 2': 'GER', 'Banja Luka': 'BIH', 'Poertschach': 'AUT', 
    'Acapulco': 'MEX', 'Antwerp': 'BEL', 'Halle': 'GER', 'Kuala Lumpur': 'MAS', 'Marrakech': 'MAR', 
    'Nottingham': 'GBR', 'Sardinia': 'ITA', 'Scottsdale': 'USA', 'Stuttgart Masters': 'GER'
}

# 遍历所有 DataFrame，生成 tourney_ioc 列
for key, df in dataframes.items():
    if "tourney_name" in df.columns:
        df["tourney_ioc"] = df["tourney_name"].map(tennis_events_ioc)

# 检查某个 DataFrame 是否成功添加列
print(dataframes["df_00_04"][["tourney_name", "tourney_ioc"]].head())
# Out:
#   tourney_name tourney_ioc
# 0     Auckland         NZL
# 1     Auckland         NZL
# 2     Auckland         NZL
# 3     Auckland         NZL
# 4     Auckland         NZL

# %%
for key, df in dataframes.items():
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16404 entries, 0 to 16403
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          16404 non-null  object
#  1   tourney_name        16404 non-null  object
#  2   surface             16404 non-null  object
#  3   draw_size           16404 non-null  int64
#  4   tourney_level       16404 non-null  object
#  5   tourney_date        16404 non-null  object
#  6   match_num           16404 non-null  int64
#  7   winner_id           16404 non-null  int64
#  8   winner_seed         6219 non-null   float64
#  9   winner_entry        1937 non-null   object
#  10  winner_name         16404 non-null  object
#  11  winner_hand         16404 non-null  object
#  12  winner_ht           15900 non-null  float64
#  13  winner_ioc          16404 non-null  object
#  14  winner_age          16402 non-null  float64
#  15  loser_id            16404 non-null  int64
#  16  loser_seed          3496 non-null   float64
#  17  loser_entry         3188 non-null   object
#  18  loser_name          16404 non-null  object
#  19  loser_hand          16404 non-null  object
#  20  loser_ht            15473 non-null  float64
#  21  loser_ioc           16404 non-null  object
#  22  loser_age           16404 non-null  float64
#  23  score               16404 non-null  object
#  24  best_of             16404 non-null  int64
#  25  round               16404 non-null  object
#  26  minutes             14425 non-null  float64
#  27  w_ace               14439 non-null  float64
#  28  w_df                14439 non-null  float64
#  29  w_svpt              14439 non-null  float64
#  30  w_1stIn             14439 non-null  float64
#  31  w_1stWon            14439 non-null  float64
#  32  w_2ndWon            14439 non-null  float64
#  33  w_SvGms             14439 non-null  float64
#  34  w_bpSaved           14439 non-null  float64
#  35  w_bpFaced           14439 non-null  float64
#  36  l_ace               14439 non-null  float64
#  37  l_df                14439 non-null  float64
#  38  l_svpt              14439 non-null  float64
#  39  l_1stIn             14439 non-null  float64
#  40  l_1stWon            14439 non-null  float64
#  41  l_2ndWon            14439 non-null  float64
#  42  l_SvGms             14439 non-null  float64
#  43  l_bpSaved           14439 non-null  float64
#  44  l_bpFaced           14439 non-null  float64
#  45  winner_rank         16202 non-null  float64
#  46  winner_rank_points  16202 non-null  float64
#  47  loser_rank          15952 non-null  float64
#  48  loser_rank_points   15952 non-null  float64
#  49  tourney_ioc         10787 non-null  object
# dtypes: float64(29), int64(5), object(16)
# memory usage: 6.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          15931 non-null  object
#  1   tourney_name        15931 non-null  object
#  2   surface             15931 non-null  object
#  3   draw_size           15931 non-null  int64
#  4   tourney_level       15931 non-null  object
#  5   tourney_date        15931 non-null  object
#  6   match_num           15931 non-null  int64
#  7   winner_id           15931 non-null  int64
#  8   winner_seed         6735 non-null   float64
#  9   winner_entry        1901 non-null   object
#  10  winner_name         15931 non-null  object
#  11  winner_hand         15931 non-null  object
#  12  winner_ht           15501 non-null  float64
#  13  winner_ioc          15931 non-null  object
#  14  winner_age          15931 non-null  float64
#  15  loser_id            15931 non-null  int64
#  16  loser_seed          3500 non-null   float64
#  17  loser_entry         3081 non-null   object
#  18  loser_name          15931 non-null  object
#  19  loser_hand          15931 non-null  object
#  20  loser_ht            15053 non-null  float64
#  21  loser_ioc           15931 non-null  object
#  22  loser_age           15931 non-null  float64
#  23  score               15931 non-null  object
#  24  best_of             15931 non-null  int64
#  25  round               15931 non-null  object
#  26  minutes             14119 non-null  float64
#  27  w_ace               14118 non-null  float64
#  28  w_df                14118 non-null  float64
#  29  w_svpt              14118 non-null  float64
#  30  w_1stIn             14118 non-null  float64
#  31  w_1stWon            14118 non-null  float64
#  32  w_2ndWon            14118 non-null  float64
#  33  w_SvGms             14118 non-null  float64
#  34  w_bpSaved           14118 non-null  float64
#  35  w_bpFaced           14118 non-null  float64
#  36  l_ace               14118 non-null  float64
#  37  l_df                14118 non-null  float64
#  38  l_svpt              14118 non-null  float64
#  39  l_1stIn             14118 non-null  float64
#  40  l_1stWon            14118 non-null  float64
#  41  l_2ndWon            14118 non-null  float64
#  42  l_SvGms             14118 non-null  float64
#  43  l_bpSaved           14118 non-null  float64
#  44  l_bpFaced           14118 non-null  float64
#  45  winner_rank         15822 non-null  float64
#  46  winner_rank_points  15822 non-null  float64
#  47  loser_rank          15586 non-null  float64
#  48  loser_rank_points   15586 non-null  float64
#  49  tourney_ioc         10106 non-null  object
# dtypes: float64(29), int64(5), object(16)
# memory usage: 6.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14899 entries, 0 to 14898
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          14899 non-null  object
#  1   tourney_name        14899 non-null  object
#  2   surface             14899 non-null  object
#  3   draw_size           14899 non-null  int64
#  4   tourney_level       14899 non-null  object
#  5   tourney_date        14899 non-null  object
#  6   match_num           14899 non-null  int64
#  7   winner_id           14899 non-null  int64
#  8   winner_seed         6447 non-null   float64
#  9   winner_entry        1719 non-null   object
#  10  winner_name         14899 non-null  object
#  11  winner_hand         14899 non-null  object
#  12  winner_ht           14585 non-null  float64
#  13  winner_ioc          14899 non-null  object
#  14  winner_age          14899 non-null  float64
#  15  loser_id            14899 non-null  int64
#  16  loser_seed          3440 non-null   float64
#  17  loser_entry         2972 non-null   object
#  18  loser_name          14899 non-null  object
#  19  loser_hand          14899 non-null  object
#  20  loser_ht            14261 non-null  float64
#  21  loser_ioc           14899 non-null  object
#  22  loser_age           14899 non-null  float64
#  23  score               14899 non-null  object
#  24  best_of             14899 non-null  int64
#  25  round               14899 non-null  object
#  26  minutes             13240 non-null  float64
#  27  w_ace               13240 non-null  float64
#  28  w_df                13240 non-null  float64
#  29  w_svpt              13240 non-null  float64
#  30  w_1stIn             13240 non-null  float64
#  31  w_1stWon            13240 non-null  float64
#  32  w_2ndWon            13240 non-null  float64
#  33  w_SvGms             13240 non-null  float64
#  34  w_bpSaved           13240 non-null  float64
#  35  w_bpFaced           13240 non-null  float64
#  36  l_ace               13240 non-null  float64
#  37  l_df                13240 non-null  float64
#  38  l_svpt              13240 non-null  float64
#  39  l_1stIn             13240 non-null  float64
#  40  l_1stWon            13240 non-null  float64
#  41  l_2ndWon            13240 non-null  float64
#  42  l_SvGms             13240 non-null  float64
#  43  l_bpSaved           13240 non-null  float64
#  44  l_bpFaced           13240 non-null  float64
#  45  winner_rank         14776 non-null  float64
#  46  winner_rank_points  14776 non-null  float64
#  47  loser_rank          14583 non-null  float64
#  48  loser_rank_points   14583 non-null  float64
#  49  tourney_ioc         10005 non-null  object
# dtypes: float64(29), int64(5), object(16)
# memory usage: 5.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14498 entries, 0 to 14497
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          14498 non-null  object
#  1   tourney_name        14498 non-null  object
#  2   surface             14498 non-null  object
#  3   draw_size           14498 non-null  int64
#  4   tourney_level       14498 non-null  object
#  5   tourney_date        14498 non-null  object
#  6   match_num           14498 non-null  int64
#  7   winner_id           14498 non-null  int64
#  8   winner_seed         6212 non-null   float64
#  9   winner_entry        1921 non-null   object
#  10  winner_name         14498 non-null  object
#  11  winner_hand         14498 non-null  object
#  12  winner_ht           14374 non-null  float64
#  13  winner_ioc          14498 non-null  object
#  14  winner_age          14497 non-null  float64
#  15  loser_id            14498 non-null  int64
#  16  loser_seed          3553 non-null   float64
#  17  loser_entry         3152 non-null   object
#  18  loser_name          14498 non-null  object
#  19  loser_hand          14494 non-null  object
#  20  loser_ht            14187 non-null  float64
#  21  loser_ioc           14498 non-null  object
#  22  loser_age           14498 non-null  float64
#  23  score               14498 non-null  object
#  24  best_of             14498 non-null  int64
#  25  round               14498 non-null  object
#  26  minutes             12648 non-null  float64
#  27  w_ace               13962 non-null  float64
#  28  w_df                13962 non-null  float64
#  29  w_svpt              13962 non-null  float64
#  30  w_1stIn             13962 non-null  float64
#  31  w_1stWon            13962 non-null  float64
#  32  w_2ndWon            13962 non-null  float64
#  33  w_SvGms             13962 non-null  float64
#  34  w_bpSaved           13962 non-null  float64
#  35  w_bpFaced           13962 non-null  float64
#  36  l_ace               13962 non-null  float64
#  37  l_df                13962 non-null  float64
#  38  l_svpt              13962 non-null  float64
#  39  l_1stIn             13962 non-null  float64
#  40  l_1stWon            13962 non-null  float64
#  41  l_2ndWon            13962 non-null  float64
#  42  l_SvGms             13962 non-null  float64
#  43  l_bpSaved           13962 non-null  float64
#  44  l_bpFaced           13962 non-null  float64
#  45  winner_rank         14423 non-null  float64
#  46  winner_rank_points  14423 non-null  float64
#  47  loser_rank          14293 non-null  float64
#  48  loser_rank_points   14293 non-null  float64
#  49  tourney_ioc         10480 non-null  object
# dtypes: float64(29), int64(5), object(16)
# memory usage: 5.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13174 entries, 0 to 13173
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          13174 non-null  object
#  1   tourney_name        13174 non-null  object
#  2   surface             13121 non-null  object
#  3   draw_size           13174 non-null  int64
#  4   tourney_level       13174 non-null  object
#  5   tourney_date        13174 non-null  object
#  6   match_num           13174 non-null  int64
#  7   winner_id           13174 non-null  int64
#  8   winner_seed         5507 non-null   float64
#  9   winner_entry        2028 non-null   object
#  10  winner_name         13174 non-null  object
#  11  winner_hand         13174 non-null  object
#  12  winner_ht           13121 non-null  float64
#  13  winner_ioc          13174 non-null  object
#  14  winner_age          13172 non-null  float64
#  15  loser_id            13174 non-null  int64
#  16  loser_seed          3249 non-null   float64
#  17  loser_entry         3029 non-null   object
#  18  loser_name          13174 non-null  object
#  19  loser_hand          13174 non-null  object
#  20  loser_ht            13023 non-null  float64
#  21  loser_ioc           13174 non-null  object
#  22  loser_age           13171 non-null  float64
#  23  score               13174 non-null  object
#  24  best_of             13174 non-null  int64
#  25  round               13174 non-null  object
#  26  minutes             12300 non-null  float64
#  27  w_ace               12627 non-null  float64
#  28  w_df                12627 non-null  float64
#  29  w_svpt              12627 non-null  float64
#  30  w_1stIn             12627 non-null  float64
#  31  w_1stWon            12627 non-null  float64
#  32  w_2ndWon            12627 non-null  float64
#  33  w_SvGms             12627 non-null  float64
#  34  w_bpSaved           12627 non-null  float64
#  35  w_bpFaced           12627 non-null  float64
#  36  l_ace               12627 non-null  float64
#  37  l_df                12627 non-null  float64
#  38  l_svpt              12627 non-null  float64
#  39  l_1stIn             12627 non-null  float64
#  40  l_1stWon            12627 non-null  float64
#  41  l_2ndWon            12627 non-null  float64
#  42  l_SvGms             12627 non-null  float64
#  43  l_bpSaved           12627 non-null  float64
#  44  l_bpFaced           12627 non-null  float64
#  45  winner_rank         13110 non-null  float64
#  46  winner_rank_points  13110 non-null  float64
#  47  loser_rank          13024 non-null  float64
#  48  loser_rank_points   13024 non-null  float64
#  49  tourney_ioc         8542 non-null   object
# dtypes: float64(29), int64(5), object(16)
# memory usage: 5.0+ MB
# None

# %%
for key, df in dataframes.items():
    if "tourney_name" in df.columns and "tourney_date" in df.columns:
        # 提取年份（假设tourney_date格式为YYYYMMDD）
        df["tourney_year"] = df["tourney_date"].astype(str).str[:4].astype(int)

        # 修改 Next Gen Finals 的 tourney_ioc 值
        df.loc[(df["tourney_name"] == "NextGen Finals") & (df["tourney_year"].between(2017, 2022)), "tourney_ioc"] = "ITA"
        df.loc[(df["tourney_name"] == "NextGen Finals") & (df["tourney_year"] >= 2023), "tourney_ioc"] = "KSA"

# %%
# 遍历所有DataFrame并检查符合条件的行
for key, df in dataframes.items():
    print(f"\n=== 检查DataFrame: {key} ===")
    
    # 检查是否存在必要列
    if "tourney_name" not in df.columns or "tourney_year" not in df.columns or "tourney_ioc" not in df.columns:
        print("缺少必要列，跳过检查")
        continue
    
    # 筛选目标行
    nextgen_matches = df[df["tourney_name"] == "NextGen Finals"]
    
    if nextgen_matches.empty:
        print("未找到 NextGen Finals 赛事")
    else:
        # 显示关键列：年份、国家代码、日期（可选）
        print(f"找到 {len(nextgen_matches)} 条记录:")
        print(nextgen_matches[["tourney_year", "tourney_ioc", "tourney_date"]].to_string(index=False))
# Out:
# === 检查DataFrame: df_00_04 ===
# 未找到 NextGen Finals 赛事
#
# === 检查DataFrame: df_05_09 ===
# 未找到 NextGen Finals 赛事
#
# === 检查DataFrame: df_10_14 ===
# 未找到 NextGen Finals 赛事
#
# === 检查DataFrame: df_15_19 ===
# 找到 47 条记录:
#  tourney_year tourney_ioc tourney_date
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2017         ITA   2017-11-06
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2018         ITA   2018-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#          2019         ITA   2019-11-05
#
# === 检查DataFrame: df_20_24 ===
# 找到 45 条记录:
#  tourney_year tourney_ioc tourney_date
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2021         ITA   2021-11-08
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2022         ITA   2022-11-07
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27
#          2023         KSA   2023-11-27

# %%
# 载入 atp_players.csv
players_file = r"F:\大四\tennis_predicton\rank\atp_players.csv"
#DtypeWarning: Columns (7) have mixed types. Specify dtype={'wikidata_id': 'str'}
df_players = pd.read_csv(players_file,dtype={'wikidata_id': 'str'})

# 确保 name_first 和 name_last 列存在
if "name_first" in df_players.columns and "name_last" in df_players.columns:
    df_players["name"] = df_players["name_first"] + " " + df_players["name_last"]

# 显示合并后的前几行数据
print(df_players[["name_first", "name_last", "name"]].head())
# Out:
#   name_first name_last              name
# 0    Gardnar    Mulloy    Gardnar Mulloy
# 1     Pancho    Segura     Pancho Segura
# 2      Frank   Sedgman     Frank Sedgman
# 3   Giuseppe     Merlo    Giuseppe Merlo
# 4    Richard  Gonzalez  Richard Gonzalez

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65989 entries, 0 to 65988
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player_id    65989 non-null  int64
#  1   name_first   65068 non-null  object
#  2   name_last    65941 non-null  object
#  3   hand         65973 non-null  object
#  4   dob          47587 non-null  float64
#  5   ioc          65319 non-null  object
#  6   height       4159 non-null   float64
#  7   wikidata_id  4894 non-null   object
#  8   name         65068 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.5+ MB

# %%
# 1. 先检查 df_players 是否有重复 player_id
duplicates = df_players[df_players.duplicated(subset=['player_id'], keep=False)]
if not duplicates.empty:
    print("Found duplicate player_id in df_players:")
    print(duplicates)

    # 处理重复 player_id（可选）
    df_players = df_players.drop_duplicates(subset=['player_id'], keep='first')

# 2. 遍历 dataframes 进行处理
for key, df in dataframes.items():
    print(f"Processing DataFrame: {key}")
    
    if all(col in df.columns for col in ["winner_id", "loser_id", "tourney_ioc"]):
        print(f"Original Data Sample:\n{df[['winner_id', 'loser_id', 'tourney_ioc']].head()}\n")

        # 3. 合并 winner_id
        df = df.merge(df_players[['player_id', 'ioc']], left_on="winner_id", right_on="player_id", how="left")
        print(f"After merging winner_id:\n{df[['winner_id', 'ioc', 'tourney_ioc']].head()}\n")

        df["w_host"] = (df["ioc"] == df["tourney_ioc"]).astype(int)
        print(f"After setting w_host:\n{df[['winner_id', 'tourney_ioc', 'ioc', 'w_host']].head()}\n")

        df.drop(columns=["player_id", "ioc"], inplace=True)  # 删除临时列

        # 4. 合并 loser_id
        df = df.merge(df_players[['player_id', 'ioc']], left_on="loser_id", right_on="player_id", how="left")
        print(f"After merging loser_id:\n{df[['loser_id', 'ioc', 'tourney_ioc']].head()}\n")

        df["l_host"] = (df["ioc"] == df["tourney_ioc"]).astype(int)
        print(f"After setting l_host:\n{df[['loser_id', 'tourney_ioc', 'ioc', 'l_host']].head()}\n")

        df.drop(columns=["player_id", "ioc"], inplace=True)  # 删除临时列

        # 5. 确保列数不变
        print(f"Final columns count: {len(df.columns)} (should match original count)\n")
        
        # 更新字典中的 dataframe
        dataframes[key] = df

    print(f"Finished processing {key}\n{'-'*50}\n")
# Out:
# Processing DataFrame: df_00_04
# Original Data Sample:
#    winner_id  loser_id tourney_ioc
# 0     103163    101543         NZL
# 1     102607    102644         NZL
# 2     103252    102238         NZL
# 3     103507    103819         NZL
# 4     102103    102765         NZL
#
# After merging winner_id:
#    winner_id  ioc tourney_ioc
# 0     103163  GER         NZL
# 1     102607  ESP         NZL
# 2     103252  ESP         NZL
# 3     103507  ESP         NZL
# 4     102103  USA         NZL
#
# After setting w_host:
#    winner_id tourney_ioc  ioc  w_host
# 0     103163         NZL  GER       0
# 1     102607         NZL  ESP       0
# 2     103252         NZL  ESP       0
# 3     103507         NZL  ESP       0
# 4     102103         NZL  USA       0
#
# After merging loser_id:
#    loser_id  ioc tourney_ioc
# 0    101543  USA         NZL
# 1    102644  ARG         NZL
# 2    102238  ESP         NZL
# 3    103819  SUI         NZL
# 4    102765  FRA         NZL
#
# After setting l_host:
#    loser_id tourney_ioc  ioc  l_host
# 0    101543         NZL  USA       0
# 1    102644         NZL  ARG       0
# 2    102238         NZL  ESP       0
# 3    103819         NZL  SUI       0
# 4    102765         NZL  FRA       0
#
# Final columns count: 53 (should match original count)
#
# Finished processing df_00_04
# --------------------------------------------------
#
# Processing DataFrame: df_05_09
# Original Data Sample:
#    winner_id  loser_id tourney_ioc
# 0     103812    102720         ESP
# 1     102845    103835         ESP
# 2     102450    103758         ESP
# 3     104076    104022         ESP
# 4     103971    103017         ESP
#
# After merging winner_id:
#    winner_id  ioc tourney_ioc
# 0     103812  ROU         ESP
# 1     102845  ESP         ESP
# 2     102450  GBR         ESP
# 3     104076  ARG         ESP
# 4     103971  SVK         ESP
#
# After setting w_host:
#    winner_id tourney_ioc  ioc  w_host
# 0     103812         ESP  ROU       0
# 1     102845         ESP  ESP       1
# 2     102450         ESP  GBR       0
# 3     104076         ESP  ARG       0
# 4     103971         ESP  SVK       0
#
# After merging loser_id:
#    loser_id  ioc tourney_ioc
# 0    102720  CZE         ESP
# 1    103835  ITA         ESP
# 2    103758  USA         ESP
# 3    104022  RUS         ESP
# 4    103017  GER         ESP
#
# After setting l_host:
#    loser_id tourney_ioc  ioc  l_host
# 0    102720         ESP  CZE       0
# 1    103835         ESP  ITA       0
# 2    103758         ESP  USA       0
# 3    104022         ESP  RUS       0
# 4    103017         ESP  GER       0
#
# Final columns count: 53 (should match original count)
#
# Finished processing df_05_09
# --------------------------------------------------
#
# Processing DataFrame: df_10_14
# Original Data Sample:
#    winner_id  loser_id tourney_ioc
# 0     104053    103429         AUS
# 1     104958    104999         AUS
# 2     104755    103813         AUS
# 3     105051    103781         AUS
# 4     104607    105194         AUS
#
# After merging winner_id:
#    winner_id  ioc tourney_ioc
# 0     104053  USA         AUS
# 1     104958  AUS         AUS
# 2     104755  FRA         AUS
# 3     105051  AUS         AUS
# 4     104607  CZE         AUS
#
# After setting w_host:
#    winner_id tourney_ioc  ioc  w_host
# 0     104053         AUS  USA       0
# 1     104958         AUS  AUS       1
# 2     104755         AUS  FRA       0
# 3     105051         AUS  AUS       1
# 4     104607         AUS  CZE       0
#
# After merging loser_id:
#    loser_id  ioc tourney_ioc
# 0    103429  AUS         AUS
# 1    104999  GER         AUS
# 2    103813  FIN         AUS
# 3    103781  AUT         AUS
# 4    105194  AUS         AUS
#
# After setting l_host:
#    loser_id tourney_ioc  ioc  l_host
# 0    103429         AUS  AUS       1
# 1    104999         AUS  GER       0
# 2    103813         AUS  FIN       0
# 3    103781         AUS  AUT       0
# 4    105194         AUS  AUS       1
#
# Final columns count: 53 (should match original count)
#
# Finished processing df_10_14
# --------------------------------------------------
#
# Processing DataFrame: df_15_19
# Original Data Sample:
#    winner_id  loser_id tourney_ioc
# 0     105357    105733         AUS
# 1     103813    106045         AUS
# 2     105902    104468         AUS
# 3     104871    104979         AUS
# 4     105373    103781         AUS
#
# After merging winner_id:
#    winner_id  ioc tourney_ioc
# 0     105357  AUS         AUS
# 1     103813  FIN         AUS
# 2     105902  AUS         AUS
# 3     104871  FRA         AUS
# 4     105373  SVK         AUS
#
# After setting w_host:
#    winner_id tourney_ioc  ioc  w_host
# 0     105357         AUS  AUS       1
# 1     103813         AUS  FIN       0
# 2     105902         AUS  AUS       1
# 3     104871         AUS  FRA       0
# 4     105373         AUS  SVK       0
#
# After merging loser_id:
#    loser_id  ioc tourney_ioc
# 0    105733  USA         AUS
# 1    106045  USA         AUS
# 2    104468  FRA         AUS
# 3    104979  KAZ         AUS
# 4    103781  AUT         AUS
#
# After setting l_host:
#    loser_id tourney_ioc  ioc  l_host
# 0    105733         AUS  USA       0
# 1    106045         AUS  USA       0
# 2    104468         AUS  FRA       0
# 3    104979         AUS  KAZ       0
# 4    103781         AUS  AUT       0
#
# Final columns count: 53 (should match original count)
#
# Finished processing df_15_19
# --------------------------------------------------
#
# Processing DataFrame: df_20_24
# Original Data Sample:
#    winner_id  loser_id tourney_ioc
# 0     104925    104745         AUS
# 1     105138    105583         AUS
# 2     104925    106421         AUS
# 3     105583    111575         AUS
# 4     104745    200282         AUS
#
# After merging winner_id:
#    winner_id  ioc tourney_ioc
# 0     104925  SRB         AUS
# 1     105138  ESP         AUS
# 2     104925  SRB         AUS
# 3     105583  SRB         AUS
# 4     104745  ESP         AUS
#
# After setting w_host:
#    winner_id tourney_ioc  ioc  w_host
# 0     104925         AUS  SRB       0
# 1     105138         AUS  ESP       0
# 2     104925         AUS  SRB       0
# 3     105583         AUS  SRB       0
# 4     104745         AUS  ESP       0
#
# After merging loser_id:
#    loser_id  ioc tourney_ioc
# 0    104745  ESP         AUS
# 1    105583  SRB         AUS
# 2    106421  RUS         AUS
# 3    111575  RUS         AUS
# 4    200282  AUS         AUS
#
# After setting l_host:
#    loser_id tourney_ioc  ioc  l_host
# 0    104745         AUS  ESP       0
# 1    105583         AUS  SRB       0
# 2    106421         AUS  RUS       0
# 3    111575         AUS  RUS       0
# 4    200282         AUS  AUS       1
#
# Final columns count: 53 (should match original count)
#
# Finished processing df_20_24
# --------------------------------------------------

# %%
for key, df in dataframes.items():
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16404 entries, 0 to 16403
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          16404 non-null  object
#  1   tourney_name        16404 non-null  object
#  2   surface             16404 non-null  object
#  3   draw_size           16404 non-null  int64
#  4   tourney_level       16404 non-null  object
#  5   tourney_date        16404 non-null  object
#  6   match_num           16404 non-null  int64
#  7   winner_id           16404 non-null  int64
#  8   winner_seed         6219 non-null   float64
#  9   winner_entry        1937 non-null   object
#  10  winner_name         16404 non-null  object
#  11  winner_hand         16404 non-null  object
#  12  winner_ht           15900 non-null  float64
#  13  winner_ioc          16404 non-null  object
#  14  winner_age          16402 non-null  float64
#  15  loser_id            16404 non-null  int64
#  16  loser_seed          3496 non-null   float64
#  17  loser_entry         3188 non-null   object
#  18  loser_name          16404 non-null  object
#  19  loser_hand          16404 non-null  object
#  20  loser_ht            15473 non-null  float64
#  21  loser_ioc           16404 non-null  object
#  22  loser_age           16404 non-null  float64
#  23  score               16404 non-null  object
#  24  best_of             16404 non-null  int64
#  25  round               16404 non-null  object
#  26  minutes             14425 non-null  float64
#  27  w_ace               14439 non-null  float64
#  28  w_df                14439 non-null  float64
#  29  w_svpt              14439 non-null  float64
#  30  w_1stIn             14439 non-null  float64
#  31  w_1stWon            14439 non-null  float64
#  32  w_2ndWon            14439 non-null  float64
#  33  w_SvGms             14439 non-null  float64
#  34  w_bpSaved           14439 non-null  float64
#  35  w_bpFaced           14439 non-null  float64
#  36  l_ace               14439 non-null  float64
#  37  l_df                14439 non-null  float64
#  38  l_svpt              14439 non-null  float64
#  39  l_1stIn             14439 non-null  float64
#  40  l_1stWon            14439 non-null  float64
#  41  l_2ndWon            14439 non-null  float64
#  42  l_SvGms             14439 non-null  float64
#  43  l_bpSaved           14439 non-null  float64
#  44  l_bpFaced           14439 non-null  float64
#  45  winner_rank         16202 non-null  float64
#  46  winner_rank_points  16202 non-null  float64
#  47  loser_rank          15952 non-null  float64
#  48  loser_rank_points   15952 non-null  float64
#  49  tourney_ioc         10787 non-null  object
#  50  tourney_year        16404 non-null  int32
#  51  w_host              16404 non-null  int32
#  52  l_host              16404 non-null  int32
# dtypes: float64(29), int32(3), int64(5), object(16)
# memory usage: 6.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15931 entries, 0 to 15930
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          15931 non-null  object
#  1   tourney_name        15931 non-null  object
#  2   surface             15931 non-null  object
#  3   draw_size           15931 non-null  int64
#  4   tourney_level       15931 non-null  object
#  5   tourney_date        15931 non-null  object
#  6   match_num           15931 non-null  int64
#  7   winner_id           15931 non-null  int64
#  8   winner_seed         6735 non-null   float64
#  9   winner_entry        1901 non-null   object
#  10  winner_name         15931 non-null  object
#  11  winner_hand         15931 non-null  object
#  12  winner_ht           15501 non-null  float64
#  13  winner_ioc          15931 non-null  object
#  14  winner_age          15931 non-null  float64
#  15  loser_id            15931 non-null  int64
#  16  loser_seed          3500 non-null   float64
#  17  loser_entry         3081 non-null   object
#  18  loser_name          15931 non-null  object
#  19  loser_hand          15931 non-null  object
#  20  loser_ht            15053 non-null  float64
#  21  loser_ioc           15931 non-null  object
#  22  loser_age           15931 non-null  float64
#  23  score               15931 non-null  object
#  24  best_of             15931 non-null  int64
#  25  round               15931 non-null  object
#  26  minutes             14119 non-null  float64
#  27  w_ace               14118 non-null  float64
#  28  w_df                14118 non-null  float64
#  29  w_svpt              14118 non-null  float64
#  30  w_1stIn             14118 non-null  float64
#  31  w_1stWon            14118 non-null  float64
#  32  w_2ndWon            14118 non-null  float64
#  33  w_SvGms             14118 non-null  float64
#  34  w_bpSaved           14118 non-null  float64
#  35  w_bpFaced           14118 non-null  float64
#  36  l_ace               14118 non-null  float64
#  37  l_df                14118 non-null  float64
#  38  l_svpt              14118 non-null  float64
#  39  l_1stIn             14118 non-null  float64
#  40  l_1stWon            14118 non-null  float64
#  41  l_2ndWon            14118 non-null  float64
#  42  l_SvGms             14118 non-null  float64
#  43  l_bpSaved           14118 non-null  float64
#  44  l_bpFaced           14118 non-null  float64
#  45  winner_rank         15822 non-null  float64
#  46  winner_rank_points  15822 non-null  float64
#  47  loser_rank          15586 non-null  float64
#  48  loser_rank_points   15586 non-null  float64
#  49  tourney_ioc         10106 non-null  object
#  50  tourney_year        15931 non-null  int32
#  51  w_host              15931 non-null  int32
#  52  l_host              15931 non-null  int32
# dtypes: float64(29), int32(3), int64(5), object(16)
# memory usage: 6.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14899 entries, 0 to 14898
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          14899 non-null  object
#  1   tourney_name        14899 non-null  object
#  2   surface             14899 non-null  object
#  3   draw_size           14899 non-null  int64
#  4   tourney_level       14899 non-null  object
#  5   tourney_date        14899 non-null  object
#  6   match_num           14899 non-null  int64
#  7   winner_id           14899 non-null  int64
#  8   winner_seed         6447 non-null   float64
#  9   winner_entry        1719 non-null   object
#  10  winner_name         14899 non-null  object
#  11  winner_hand         14899 non-null  object
#  12  winner_ht           14585 non-null  float64
#  13  winner_ioc          14899 non-null  object
#  14  winner_age          14899 non-null  float64
#  15  loser_id            14899 non-null  int64
#  16  loser_seed          3440 non-null   float64
#  17  loser_entry         2972 non-null   object
#  18  loser_name          14899 non-null  object
#  19  loser_hand          14899 non-null  object
#  20  loser_ht            14261 non-null  float64
#  21  loser_ioc           14899 non-null  object
#  22  loser_age           14899 non-null  float64
#  23  score               14899 non-null  object
#  24  best_of             14899 non-null  int64
#  25  round               14899 non-null  object
#  26  minutes             13240 non-null  float64
#  27  w_ace               13240 non-null  float64
#  28  w_df                13240 non-null  float64
#  29  w_svpt              13240 non-null  float64
#  30  w_1stIn             13240 non-null  float64
#  31  w_1stWon            13240 non-null  float64
#  32  w_2ndWon            13240 non-null  float64
#  33  w_SvGms             13240 non-null  float64
#  34  w_bpSaved           13240 non-null  float64
#  35  w_bpFaced           13240 non-null  float64
#  36  l_ace               13240 non-null  float64
#  37  l_df                13240 non-null  float64
#  38  l_svpt              13240 non-null  float64
#  39  l_1stIn             13240 non-null  float64
#  40  l_1stWon            13240 non-null  float64
#  41  l_2ndWon            13240 non-null  float64
#  42  l_SvGms             13240 non-null  float64
#  43  l_bpSaved           13240 non-null  float64
#  44  l_bpFaced           13240 non-null  float64
#  45  winner_rank         14776 non-null  float64
#  46  winner_rank_points  14776 non-null  float64
#  47  loser_rank          14583 non-null  float64
#  48  loser_rank_points   14583 non-null  float64
#  49  tourney_ioc         10005 non-null  object
#  50  tourney_year        14899 non-null  int32
#  51  w_host              14899 non-null  int32
#  52  l_host              14899 non-null  int32
# dtypes: float64(29), int32(3), int64(5), object(16)
# memory usage: 5.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14498 entries, 0 to 14497
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          14498 non-null  object
#  1   tourney_name        14498 non-null  object
#  2   surface             14498 non-null  object
#  3   draw_size           14498 non-null  int64
#  4   tourney_level       14498 non-null  object
#  5   tourney_date        14498 non-null  object
#  6   match_num           14498 non-null  int64
#  7   winner_id           14498 non-null  int64
#  8   winner_seed         6212 non-null   float64
#  9   winner_entry        1921 non-null   object
#  10  winner_name         14498 non-null  object
#  11  winner_hand         14498 non-null  object
#  12  winner_ht           14374 non-null  float64
#  13  winner_ioc          14498 non-null  object
#  14  winner_age          14497 non-null  float64
#  15  loser_id            14498 non-null  int64
#  16  loser_seed          3553 non-null   float64
#  17  loser_entry         3152 non-null   object
#  18  loser_name          14498 non-null  object
#  19  loser_hand          14494 non-null  object
#  20  loser_ht            14187 non-null  float64
#  21  loser_ioc           14498 non-null  object
#  22  loser_age           14498 non-null  float64
#  23  score               14498 non-null  object
#  24  best_of             14498 non-null  int64
#  25  round               14498 non-null  object
#  26  minutes             12648 non-null  float64
#  27  w_ace               13962 non-null  float64
#  28  w_df                13962 non-null  float64
#  29  w_svpt              13962 non-null  float64
#  30  w_1stIn             13962 non-null  float64
#  31  w_1stWon            13962 non-null  float64
#  32  w_2ndWon            13962 non-null  float64
#  33  w_SvGms             13962 non-null  float64
#  34  w_bpSaved           13962 non-null  float64
#  35  w_bpFaced           13962 non-null  float64
#  36  l_ace               13962 non-null  float64
#  37  l_df                13962 non-null  float64
#  38  l_svpt              13962 non-null  float64
#  39  l_1stIn             13962 non-null  float64
#  40  l_1stWon            13962 non-null  float64
#  41  l_2ndWon            13962 non-null  float64
#  42  l_SvGms             13962 non-null  float64
#  43  l_bpSaved           13962 non-null  float64
#  44  l_bpFaced           13962 non-null  float64
#  45  winner_rank         14423 non-null  float64
#  46  winner_rank_points  14423 non-null  float64
#  47  loser_rank          14293 non-null  float64
#  48  loser_rank_points   14293 non-null  float64
#  49  tourney_ioc         10480 non-null  object
#  50  tourney_year        14498 non-null  int32
#  51  w_host              14498 non-null  int32
#  52  l_host              14498 non-null  int32
# dtypes: float64(29), int32(3), int64(5), object(16)
# memory usage: 5.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13174 entries, 0 to 13173
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          13174 non-null  object
#  1   tourney_name        13174 non-null  object
#  2   surface             13121 non-null  object
#  3   draw_size           13174 non-null  int64
#  4   tourney_level       13174 non-null  object
#  5   tourney_date        13174 non-null  object
#  6   match_num           13174 non-null  int64
#  7   winner_id           13174 non-null  int64
#  8   winner_seed         5507 non-null   float64
#  9   winner_entry        2028 non-null   object
#  10  winner_name         13174 non-null  object
#  11  winner_hand         13174 non-null  object
#  12  winner_ht           13121 non-null  float64
#  13  winner_ioc          13174 non-null  object
#  14  winner_age          13172 non-null  float64
#  15  loser_id            13174 non-null  int64
#  16  loser_seed          3249 non-null   float64
#  17  loser_entry         3029 non-null   object
#  18  loser_name          13174 non-null  object
#  19  loser_hand          13174 non-null  object
#  20  loser_ht            13023 non-null  float64
#  21  loser_ioc           13174 non-null  object
#  22  loser_age           13171 non-null  float64
#  23  score               13174 non-null  object
#  24  best_of             13174 non-null  int64
#  25  round               13174 non-null  object
#  26  minutes             12300 non-null  float64
#  27  w_ace               12627 non-null  float64
#  28  w_df                12627 non-null  float64
#  29  w_svpt              12627 non-null  float64
#  30  w_1stIn             12627 non-null  float64
#  31  w_1stWon            12627 non-null  float64
#  32  w_2ndWon            12627 non-null  float64
#  33  w_SvGms             12627 non-null  float64
#  34  w_bpSaved           12627 non-null  float64
#  35  w_bpFaced           12627 non-null  float64
#  36  l_ace               12627 non-null  float64
#  37  l_df                12627 non-null  float64
#  38  l_svpt              12627 non-null  float64
#  39  l_1stIn             12627 non-null  float64
#  40  l_1stWon            12627 non-null  float64
#  41  l_2ndWon            12627 non-null  float64
#  42  l_SvGms             12627 non-null  float64
#  43  l_bpSaved           12627 non-null  float64
#  44  l_bpFaced           12627 non-null  float64
#  45  winner_rank         13110 non-null  float64
#  46  winner_rank_points  13110 non-null  float64
#  47  loser_rank          13024 non-null  float64
#  48  loser_rank_points   13024 non-null  float64
#  49  tourney_ioc         8542 non-null   object
#  50  tourney_year        13174 non-null  int32
#  51  w_host              13174 non-null  int32
#  52  l_host              13174 non-null  int32
# dtypes: float64(29), int32(3), int64(5), object(16)
# memory usage: 5.2+ MB
# None

# %% [markdown]
# 保存

# %%
output_directory = os.path.join("..", "dataset", "processed_data")
os.makedirs(output_directory, exist_ok=True)  # 创建目录（如果不存在）
for key, df in dataframes.items():
    output_file = os.path.join(output_directory, f"{key}_merged.csv")
    df.to_csv(output_file, index=False, encoding="utf-8-sig")
    print(f"已保存: {output_file}")

# %% [markdown]
# 检查名字重复值、map至dataframes

# %% [markdown]
# # 先找到所有重复的 name
# duplicate_names = df_players[df_players.duplicated(subset=['name'], keep=False)]
#
# # 按 name 排序，让相同 name 的行聚集在一起
# duplicate_names = duplicate_names.sort_values(by=['name'])
#
# # 打印结果
# print(duplicate_names)

# %% [markdown]
# # 1. 检查 df_players 是否有重复 name
# duplicates = df_players[df_players.duplicated(subset=['name'], keep=False)]
#
# if not duplicates.empty:
#     print("Found duplicate names in df_players:")
#     print(duplicates)
#
#     # 2. 选择一种方案来处理
#     # 方案 1: 手动检查后修改
#     # print("Please manually check and update df_players!")
#
#     # 方案 2: 只保留第一条记录
#     # df_players = df_players.drop_duplicates(subset=['name'], keep='first')
#
#     # 方案 3: 合并不同 ioc 值
#     # df_players = df_players.groupby('name', as_index=False).agg({'ioc': lambda x: ','.join(x.unique())})
#
#     # 方案 4: 选择出现次数最多的 ioc
#     df_players = df_players.groupby('name', as_index=False).agg(lambda x: x.value_counts().idxmax() if x.nunique() > 1 else x.iloc[0])
#
#     print("After deduplication, df_players is unique:")
#     print(df_players)
#
# # 3. 继续后续的 merge 逻辑

# %% [markdown]
# # 确保 df_players 的 name 唯一（预处理）
# df_players = df_players.drop_duplicates(subset='name', keep='first')
#
# # 创建 name 到 ioc 的映射字典
# name_to_ioc = df_players.set_index('name')['ioc'].to_dict()
#
# for key, df in dataframes.items():
#     print(f"Processing DataFrame: {key}")
#
#     if all(col in df.columns for col in ["winner_name", "loser_name", "tourney_ioc"]):
#         # 使用 map 直接映射，不会改变行数
#         df["w_host"] = df["winner_name"].map(name_to_ioc).eq(df["tourney_ioc"]).astype(int)
#         df["l_host"] = df["loser_name"].map(name_to_ioc).eq(df["tourney_ioc"]).astype(int)
#
#         dataframes[key] = df

# %% [markdown]
# duplicate_names.head(100)
