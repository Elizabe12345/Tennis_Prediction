# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pylab import mpl
# 设置显示中文字体
mpl.rcParams["font.sans-serif"] = ["SimHei"]
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
file_paths = [
    f"../dataset/processed_data/df_{start:02d}_{end:02d}_eloed.csv"
    for start, end in zip(range(0, 25, 5), range(4, 29, 5))
]

# 读取数据并存入字典
dfs = {f"df_{i}": pd.read_csv(file,low_memory=False) for i, file in zip(["00_04", "05_09", "10_14", "15_19", "20_24"], file_paths)}

# 访问
print(dfs["df_00_04"].columns)  # 查看 2000-2004 年数据的前几行
# Out:
# Index(['tourney_id', 'tourney_name', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points',
#        'tourney_ioc', 'tourney_year', 'w_host', 'l_host', 'surface_Clay',
#        'surface_Grass', 'surface_Hard', 'round_code', 'winner_seed_bucket',
#        'loser_seed_bucket', 'win_sets', 'lose_sets', 'total_win_games',
#        'total_lose_games', 'game_diff', 'ret', 'winner_elo_before',
#        'loser_elo_before', 'winner_elo_after', 'loser_elo_after',
#        'expected_score', 'elo_prediction_error'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

def safe_divide(numerator, denominator):
    """分母为0时返回0的安全除法"""
    return np.divide(numerator, denominator, out=np.zeros_like(numerator), where=(denominator != 0))

for key in dfs:
    df = dfs[key].copy()
    
    # 预处理基础字段
    base_cols = ['minutes', 'w_svpt', 'l_svpt', 'w_1stIn', 'l_1stIn', 
                'w_SvGms', 'l_SvGms', 'w_bpSaved', 'l_bpSaved']
    df[base_cols] = df[base_cols].fillna(0)
    
    # 计算核心指标
    # 1. 底线相持程度
    df['baseline_rally'] = safe_divide(df['minutes'], df['w_svpt'] + df['l_svpt'])
    
    # 2. Ace率 & DF率
    for side in ['w', 'l']:
        # Ace率
        df[f'{side}_ace_rate'] = safe_divide(df[f'{side}_ace'], df[f'{side}_svpt'])
        
        # DF率（二发次数 = 总发球 - 一发成功 - 双误）
        second_serve = df[f'{side}_svpt'] - df[f'{side}_1stIn'] - df[f'{side}_df']
        second_serve = second_serve.clip(lower=0)  # 避免负数
        df[f'{side}_df_rate'] = safe_divide(df[f'{side}_df'], second_serve)
        
        # 发球得分率
        second_won = safe_divide(df[f'{side}_2ndWon'], second_serve) * second_serve
        df[f'{side}_serve_win_rate'] = safe_divide(
            df[f'{side}_1stWon'] + second_won, 
            df[f'{side}_svpt']
        )
        
        # 发球效率
        df[f'{side}_serve_efficiency'] = safe_divide(
            df[f'{side}_svpt'], 
            df[f'{side}_SvGms']
        )
    
    # 3. 关键分能力
    total_bp = df['w_bpFaced'] + df['l_bpFaced']
    df['w_clutch_ability'] = safe_divide(
        df['w_bpSaved'] + df['l_bpFaced'] - df['l_bpSaved'], 
        total_bp
    )
    df['l_clutch_ability'] = safe_divide(
        df['l_bpSaved'] + df['w_bpFaced'] - df['w_bpSaved'], 
        total_bp
    )
    #4 激烈程度
    df['intensity'] = safe_divide(
        df['w_bpFaced'] + df['l_bpFaced'], 
        df['w_SvGms'] + df['l_SvGms']
        
    )
    
    dfs[key] = df

# %%
# 定义需要检查的列（根据计算逻辑生成的新列）
calculated_columns = [
    'baseline_rally','intensity',
    'w_ace_rate', 'l_ace_rate',
    'w_df_rate', 'l_df_rate',
    'w_serve_win_rate', 'l_serve_win_rate',
    'w_serve_efficiency', 'l_serve_efficiency',
    'w_clutch_ability', 'l_clutch_ability'
]

# 遍历每个数据集
for dataset_name, df in dfs.items():
    print(f"\n=== {dataset_name} 空值分析 ===")
    
    # 统计每个特征的空值情况
    null_report = df[calculated_columns].isnull().sum().to_frame(name='空值数量')
    
    # 显示空值统计
    print(null_report)
    
    # 显示分母可能为0的列情况
    print("\n分母列零值统计:")
    denominator_cols = ['w_svpt', 'l_svpt', 'w_SvGms', 'l_SvGms','w_bpFaced','l_bpFaced']
    zero_counts = (df[denominator_cols] == 0).sum()
    print(zero_counts)

    print("\n" + "="*60 + "\n")
# Out:
# === df_00_04 空值分析 ===
#                     空值数量
# baseline_rally         0
# intensity              0
# w_ace_rate             0
# l_ace_rate             0
# w_df_rate              0
# l_df_rate              0
# w_serve_win_rate       0
# l_serve_win_rate       0
# w_serve_efficiency     0
# l_serve_efficiency     0
# w_clutch_ability       0
# l_clutch_ability       0
#
# 分母列零值统计:
# w_svpt          0
# l_svpt          0
# w_SvGms         0
# l_SvGms         0
# w_bpFaced    1129
# l_bpFaced      14
# dtype: int64
#
# ============================================================
#
#
# === df_05_09 空值分析 ===
#                     空值数量
# baseline_rally         0
# intensity              0
# w_ace_rate             0
# l_ace_rate             0
# w_df_rate              0
# l_df_rate              0
# w_serve_win_rate       0
# l_serve_win_rate       0
# w_serve_efficiency     0
# l_serve_efficiency     0
# w_clutch_ability       0
# l_clutch_ability       0
#
# 分母列零值统计:
# w_svpt          0
# l_svpt          0
# w_SvGms         2
# l_SvGms         2
# w_bpFaced    1257
# l_bpFaced      19
# dtype: int64
#
# ============================================================
#
#
# === df_10_14 空值分析 ===
#                     空值数量
# baseline_rally         0
# intensity              0
# w_ace_rate             0
# l_ace_rate             0
# w_df_rate              0
# l_df_rate              0
# w_serve_win_rate       0
# l_serve_win_rate       0
# w_serve_efficiency     0
# l_serve_efficiency     0
# w_clutch_ability       0
# l_clutch_ability       0
#
# 分母列零值统计:
# w_svpt          0
# l_svpt          2
# w_SvGms         0
# l_SvGms         2
# w_bpFaced    1220
# l_bpFaced      22
# dtype: int64
#
# ============================================================
#
#
# === df_15_19 空值分析 ===
#                     空值数量
# baseline_rally         0
# intensity              0
# w_ace_rate             0
# l_ace_rate             0
# w_df_rate              0
# l_df_rate              0
# w_serve_win_rate       0
# l_serve_win_rate       0
# w_serve_efficiency     0
# l_serve_efficiency     0
# w_clutch_ability       0
# l_clutch_ability       0
#
# 分母列零值统计:
# w_svpt          1
# l_svpt          1
# w_SvGms         0
# l_SvGms         0
# w_bpFaced    1301
# l_bpFaced      47
# dtype: int64
#
# ============================================================
#
#
# === df_20_24 空值分析 ===
#                     空值数量
# baseline_rally         0
# intensity              0
# w_ace_rate             0
# l_ace_rate             0
# w_df_rate              0
# l_df_rate              0
# w_serve_win_rate       0
# l_serve_win_rate       0
# w_serve_efficiency     0
# l_serve_efficiency     0
# w_clutch_ability       0
# l_clutch_ability       0
#
# 分母列零值统计:
# w_svpt          0
# l_svpt          0
# w_SvGms         0
# l_SvGms         0
# w_bpFaced    1109
# l_bpFaced      20
# dtype: int64
#
# ============================================================

# %%
# 计算指标的列
metrics = ['baseline_rally','intensity', 'w_ace_rate', 'w_df_rate', 'w_serve_win_rate', 
           'w_serve_efficiency', 'w_clutch_ability','l_clutch_ability']

# 存储所有处理后的数据
player_stats = []

for key, df in dfs.items():
    df = df.copy()  # 避免修改原数据
    
    # 重新整理数据，使 winner_id 和 loser_id 作为 player_id
    winner_df = df[['tourney_year', 'winner_id'] + metrics].rename(columns={'winner_id': 'player_id'})
    loser_df = df[['tourney_year', 'loser_id'] + metrics].rename(columns={'loser_id': 'player_id'})
    
    # 合并 winner 和 loser 数据
    player_df = pd.concat([winner_df, loser_df], ignore_index=True)

    # 计算每个 player_id 在每个 tourney_year 下的均值和方差
    agg_funcs = {col: ['mean', 'var'] for col in metrics}
    yearly_stats = player_df.groupby(['tourney_year', 'player_id']).agg(agg_funcs)

    # 重命名列，使其更易读
    yearly_stats.columns = [f"{col}_{stat}" for col, stat in yearly_stats.columns]

    # 重置索引
    yearly_stats = yearly_stats.reset_index()
    
    # 存储结果
    player_stats.append(yearly_stats)

# 合并所有年份的数据
final_player_stats = pd.concat(player_stats, ignore_index=True)

# 显示前几行数据
print(final_player_stats.head(5))
# Out:
#    tourney_year  player_id  baseline_rally_mean  baseline_rally_var  \
# 0          2000     101086             0.636083            0.001991
# 1          2000     101150             0.666488            0.004232
# 2          2000     101167             0.641509                 NaN
# 3          2000     101185             0.636742            0.002580
# 4          2000     101191             0.562961            0.003850
#
#    intensity_mean  intensity_var  w_ace_rate_mean  w_ace_rate_var  \
# 0        0.705618       0.095776         0.061910        0.001649
# 1        0.610268       0.049910         0.075316        0.002218
# 2        0.666667            NaN         0.090909             NaN
# 3        0.832784       0.072028         0.053993        0.001525
# 4        0.684028       0.033010         0.115196        0.002030
#
#    w_df_rate_mean  w_df_rate_var  w_serve_win_rate_mean  w_serve_win_rate_var  \
# 0        0.119658       0.013084               0.654798              0.004037
# 1        0.087567       0.003117               0.675962              0.005189
# 2        0.095238            NaN               0.654545                   NaN
# 3        0.112757       0.005460               0.643656              0.000902
# 4        0.016129       0.000520               0.644118              0.006246
#
#    w_serve_efficiency_mean  w_serve_efficiency_var  w_clutch_ability_mean  \
# 0                 6.231934                0.426907               0.543299
# 1                 6.347479                0.718048               0.546395
# 2                 6.875000                     NaN               0.500000
# 3                 6.285714                0.492705               0.469771
# 4                 7.583333                1.680556               0.734615
#
#    w_clutch_ability_var  l_clutch_ability_mean  l_clutch_ability_var
# 0              0.020484               0.456701              0.020484
# 1              0.021177               0.453605              0.021177
# 2                   NaN               0.500000                   NaN
# 3              0.018769               0.530229              0.018769
# 4              0.002396               0.265385              0.002396

# %% [markdown]
# ### 数据重组

# %%
def process_single_df(df):
    """处理单个原始比赛数据表"""
    # 生成赢家视角
    winner_df = df[[
        'tourney_id', 'tourney_date', 'round_code', 'best_of',
        'surface_Clay', 'surface_Grass', 'surface_Hard',
        'winner_id', 'loser_id', 'winner_seed_bucket', 'winner_entry', 'w_host',
        'winner_hand', 'winner_ht', 'winner_age', 
        'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'baseline_rally','intensity',
        'w_ace_rate', 'w_df_rate', 'w_serve_win_rate', 'w_serve_efficiency',
        'w_clutch_ability',  'win_sets', 'total_win_games', 'ret',
        'winner_elo_before','winner_elo_after'
       
        
    ]].copy()
    
    # 生成输家视角
    loser_df = df[[
        'tourney_id', 'tourney_date', 'round_code', 'best_of',
         'surface_Clay', 'surface_Grass', 'surface_Hard',
        'loser_id', 'winner_id', 'loser_seed_bucket', 'loser_entry', 'l_host',
        'loser_hand', 'loser_ht', 'loser_age', 
        'l_ace', 'l_df', 'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon',
        'l_SvGms', 'l_bpSaved', 'l_bpFaced', 'baseline_rally','intensity',
        'l_ace_rate', 'l_df_rate', 'l_serve_win_rate', 'l_serve_efficiency',
        'l_clutch_ability', 'lose_sets', 'total_lose_games', 'ret',
        'loser_elo_before','loser_elo_after'
    ]].copy()
    
    # 统一列名
    common_columns = [
        'tourney_id', 'tourney_date', 'round_code', 'best_of',
        'surface_Clay', 'surface_Grass', 'surface_Hard',
        'player_id', 'opponent_id', 'seed_bucket', 'entry', 'host',
        'hand', 'ht', 'age', 
        'ace', 'df', 'svpt', 'fstIn', 'fstWon', 'sndWon',
        'SvGms', 'bpSaved', 'bpFaced', 'baseline_rally','intensity',
        'ace_rate', 'df_rate', 'serve_win_rate', 'serve_efficiency',
        'clutch_ability',  'sets', 'games', 'ret',
        'elo_before','elo_after'
    ]
    
    winner_df.columns = common_columns
    loser_df.columns = common_columns
    
    # 标记结果
    winner_df['result'] = 1
    loser_df['result'] = 0
    
    return pd.concat([winner_df, loser_df], ignore_index=True)

processed_dfs = {}
for name, df in dfs.items():  # 遍历每个数据表
    processed_dfs[name] = process_single_df(df)

# 合并所有数据（如果需要）
player_df = pd.concat(processed_dfs.values(), ignore_index=True)

# 按时间排序 + 重置索引
player_df = player_df.sort_values(['tourney_date', 'tourney_id']).reset_index(drop=True)

# %%
player_df.head(1)
# Out:
#   tourney_id tourney_date  round_code  best_of  surface_Clay  surface_Grass  \
# 0   2000-339   2000-01-03         4.0        3             0              0
#
#    surface_Hard  player_id  opponent_id  seed_bucket  entry  host  hand  \
# 0             1     102765       101792          6.0      1     0     1
#
#       ht   age  ace   df  svpt  fstIn  fstWon  sndWon  SvGms  bpSaved  \
# 0  185.0  23.7  6.0  2.0  81.0   41.0    31.0    20.0   11.0      7.0
#
#    bpFaced  baseline_rally  intensity  ace_rate   df_rate  serve_win_rate  \
# 0      9.0        0.651613   0.818182  0.074074  0.052632         0.62963
#
#    serve_efficiency  clutch_ability  sets  games  ret   elo_before  \
# 0          7.363636        0.555556     2     14    0  3054.265806
#
#      elo_after  result
# 0  3054.265806       1

# %% [markdown]
# ###  使用两种方式估计历史表现 取平均值

# %%
# 确保 tourney_date 为 datetime 类型
player_df['tourney_date'] = pd.to_datetime(player_df['tourney_date'])

# 指定需要计算历史平均值的列
cols_to_average = [
    'ace', 'df', 'svpt', 'fstIn', 'fstWon', 'sndWon',
    'SvGms', 'bpSaved', 'bpFaced', 'baseline_rally','intensity',
    'ace_rate', 'df_rate', 'serve_win_rate', 'serve_efficiency', 'clutch_ability'
]

# 按 player_id 和 tourney_date 排序，确保时间顺序正确
player_df = player_df.sort_values(by=['player_id', 'tourney_date'])

# 利用 transform 保证输出 Series 的索引和原始 DataFrame 一致
# 计算历史平均值并填充 NaN
for col in cols_to_average:
    hist_col = col + '_hist'
    player_df[hist_col] = player_df.groupby('player_id')[col].transform(
        lambda x: x.expanding().mean().shift(1)
    )
    # 如果是第一场比赛（NaN），则填充当前值
    player_df[hist_col] = player_df[hist_col].fillna(player_df[col])

# 查看结果
print(player_df.head())
# Out:
#       tourney_id tourney_date  round_code  best_of  surface_Clay  \
# 74029   2013-414   2013-07-15         2.0        3             1
# 77663   2014-308   2014-04-28         3.0        3             1
# 78959   2014-321   2014-07-07         3.0        3             1
# 78972   2014-414   2014-07-14         3.0        3             1
# 78993   2014-414   2014-07-14         5.0        3             1
#
#        surface_Grass  surface_Hard  player_id  opponent_id  seed_bucket  \
# 74029              0             0     100644       105138          0.0
# 77663              0             0     100644       103781          0.0
# 78959              0             0     100644       104586          0.0
# 78972              0             0     100644       104022          0.0
# 78993              0             0     100644       104735          0.0
#
#        entry  host  hand     ht   age  ace   df  svpt  fstIn  fstWon  sndWon  \
# 74029      0     1     1  198.0  16.2  1.0  7.0  39.0   14.0     7.0     6.0
# 77663      0     1     1  198.0  17.0  1.0  1.0  44.0   20.0     9.0     8.0
# 78959      0     1     1  198.0  17.2  6.0  8.0  93.0   54.0    35.0    24.0
# 78972      0     1     1  198.0  17.2  0.0  6.0  77.0   36.0    25.0    23.0
# 78993      0     1     1  198.0  17.2  6.0  4.0  82.0   44.0    31.0    15.0
#
#        SvGms  bpSaved  bpFaced  baseline_rally  intensity  ace_rate   df_rate  \
# 74029    8.0      2.0      8.0        0.705263   1.000000  0.025641  0.388889
# 77663    7.0      2.0      7.0        0.692308   0.933333  0.022727  0.043478
# 78959   12.0      2.0      4.0        0.575419   0.291667  0.064516  0.258065
# 78972   12.0      3.0      5.0        0.736196   0.666667  0.000000  0.171429
# 78993   13.0      7.0     11.0        0.765432   0.814815  0.073171  0.117647
#
#        serve_win_rate  serve_efficiency  clutch_ability  sets  games  ret  \
# 74029        0.333333          4.875000        0.294118     0      5    0
# 77663        0.386364          6.285714        0.214286     0      3    0
# 78959        0.634409          7.750000        0.571429     0     12    0
# 78972        0.623377          6.416667        0.437500     2     14    0
# 78993        0.560976          6.307692        0.500000     2     13    0
#
#         elo_before    elo_after  result  ace_hist   df_hist  svpt_hist  \
# 74029  1600.200888  1600.200888       0  1.000000  7.000000  39.000000
# 77663  1600.200888  1600.200888       0  1.000000  7.000000  39.000000
# 78959  1600.200888  1600.200888       0  1.000000  4.000000  41.500000
# 78972  1600.200888  1600.200888       1  2.666667  5.333333  58.666667
# 78993  1600.200888  1600.200888       1  2.000000  5.500000  63.250000
#
#        fstIn_hist  fstWon_hist  sndWon_hist  SvGms_hist  bpSaved_hist  \
# 74029   14.000000          7.0     6.000000        8.00          2.00
# 77663   14.000000          7.0     6.000000        8.00          2.00
# 78959   17.000000          8.0     7.000000        7.50          2.00
# 78972   29.333333         17.0    12.666667        9.00          2.00
# 78993   31.000000         19.0    15.250000        9.75          2.25
#
#        bpFaced_hist  baseline_rally_hist  intensity_hist  ace_rate_hist  \
# 74029      8.000000             0.705263        1.000000       0.025641
# 77663      8.000000             0.705263        1.000000       0.025641
# 78959      7.500000             0.698785        0.966667       0.024184
# 78972      6.333333             0.657663        0.741667       0.037628
# 78993      6.000000             0.677297        0.722917       0.028221
#
#        df_rate_hist  serve_win_rate_hist  serve_efficiency_hist  \
# 74029      0.388889             0.333333               4.875000
# 77663      0.388889             0.333333               4.875000
# 78959      0.216184             0.359848               5.580357
# 78972      0.230144             0.451369               6.303571
# 78993      0.215465             0.494371               6.331845
#
#        clutch_ability_hist
# 74029             0.294118
# 77663             0.294118
# 78959             0.254202
# 78972             0.359944
# 78993             0.379333

# %% [markdown]
# # 确保 tourney_date 为 datetime 类型
# player_df['tourney_date'] = pd.to_datetime(player_df['tourney_date'])
#
# # 指定需要计算历史平均值的列
# cols_to_average = [
#     'ace', 'df', 'svpt', 'fstIn', 'fstWon', 'sndWon',
#     'SvGms', 'bpSaved', 'bpFaced', 'baseline_rally','intensity',
#     'ace_rate', 'df_rate', 'serve_win_rate', 'serve_efficiency', 'clutch_ability'
# ]
#
# # 按 player_id 和 tourney_date 排序，确保时间顺序正确
# player_df = player_df.sort_values(by=['player_id', 'tourney_date'])
#
# # 指定指数衰减因子（α = 2 / (span + 1)，span 可调整）
# span = 7  # 你可以根据需要调整这个参数
# alpha = 2 / (span + 1)
#
# # 计算指数加权移动平均，并填充 NaN
# for col in cols_to_average:
#     hist_col_e = col + '_hist_e'
#     player_df[hist_col_e] = player_df.groupby('player_id')[col].transform(
#         lambda x: x.shift(1).ewm(alpha=alpha, adjust=False).mean()
#     )
#     # 如果是第一场比赛（NaN），则填充当前值
#     player_df[hist_col_e] = player_df[hist_col_e].fillna(player_df[col])
#
# # 查看结果
# print(player_df.head())

# %%
player_df.isna().sum()
# Out:
# tourney_id               0
# tourney_date             0
# round_code               0
# best_of                  0
# surface_Clay             0
# surface_Grass            0
# surface_Hard             0
# player_id                0
# opponent_id              0
# seed_bucket              0
# entry                    0
# host                     0
# hand                     0
# ht                       0
# age                      0
# ace                      0
# df                       0
# svpt                     0
# fstIn                    0
# fstWon                   0
# sndWon                   0
# SvGms                    0
# bpSaved                  0
# bpFaced                  0
# baseline_rally           0
# intensity                0
# ace_rate                 0
# df_rate                  0
# serve_win_rate           0
# serve_efficiency         0
# clutch_ability           0
# sets                     0
# games                    0
# ret                      0
# elo_before               0
# elo_after                0
# result                   0
# ace_hist                 0
# df_hist                  0
# svpt_hist                0
# fstIn_hist               0
# fstWon_hist              0
# sndWon_hist              0
# SvGms_hist               0
# bpSaved_hist             0
# bpFaced_hist             0
# baseline_rally_hist      0
# intensity_hist           0
# ace_rate_hist            0
# df_rate_hist             0
# serve_win_rate_hist      0
# serve_efficiency_hist    0
# clutch_ability_hist      0
# dtype: int64

# %%
player_df.columns
# Out:
# Index(['tourney_id', 'tourney_date', 'round_code', 'best_of', 'surface_Clay',
#        'surface_Grass', 'surface_Hard', 'player_id', 'opponent_id',
#        'seed_bucket', 'entry', 'host', 'hand', 'ht', 'age', 'ace', 'df',
#        'svpt', 'fstIn', 'fstWon', 'sndWon', 'SvGms', 'bpSaved', 'bpFaced',
#        'baseline_rally', 'intensity', 'ace_rate', 'df_rate', 'serve_win_rate',
#        'serve_efficiency', 'clutch_ability', 'sets', 'games', 'ret',
#        'elo_before', 'elo_after', 'result', 'ace_hist', 'df_hist', 'svpt_hist',
#        'fstIn_hist', 'fstWon_hist', 'sndWon_hist', 'SvGms_hist',
#        'bpSaved_hist', 'bpFaced_hist', 'baseline_rally_hist', 'intensity_hist',
#        'ace_rate_hist', 'df_rate_hist', 'serve_win_rate_hist',
#        'serve_efficiency_hist', 'clutch_ability_hist'],
#       dtype='object')

# %%
player_df.to_csv(r"..\dataset\processed_data\player_expanded.csv", index=False, encoding="utf-8-sig")

# %%
player_df.columns
# Out:
# Index(['tourney_id', 'tourney_date', 'round_code', 'best_of', 'surface_Clay',
#        'surface_Grass', 'surface_Hard', 'player_id', 'opponent_id',
#        'seed_bucket', 'entry', 'host', 'hand', 'ht', 'age', 'ace', 'df',
#        'svpt', 'fstIn', 'fstWon', 'sndWon', 'SvGms', 'bpSaved', 'bpFaced',
#        'baseline_rally', 'intensity', 'ace_rate', 'df_rate', 'serve_win_rate',
#        'serve_efficiency', 'clutch_ability', 'sets', 'games', 'ret',
#        'elo_before', 'elo_after', 'result', 'ace_hist', 'df_hist', 'svpt_hist',
#        'fstIn_hist', 'fstWon_hist', 'sndWon_hist', 'SvGms_hist',
#        'bpSaved_hist', 'bpFaced_hist', 'baseline_rally_hist', 'intensity_hist',
#        'ace_rate_hist', 'df_rate_hist', 'serve_win_rate_hist',
#        'serve_efficiency_hist', 'clutch_ability_hist'],
#       dtype='object')

# %% [markdown]
# ### 构建包含历史数据的比赛数据

# %%
# 复制 player_df，分别作为 player1 和 player2
player1_df = player_df.copy()
player2_df = player_df.copy()

# 给 player1 相关列加前缀
player1_df = player1_df.rename(columns={
    col: f'player1_{col}' for col in player_df.columns if col not in ['tourney_id', 'tourney_date', 'round_code', 'best_of', 'surface_Clay', 'surface_Grass', 'surface_Hard', 'player_id', 'opponent_id','baseline_rally', 'intensity']
})
player1_df = player1_df.rename(columns={'player_id': 'player1_id', 'opponent_id': 'player2_id'})

# 给 player2 相关列加前缀
player2_df = player2_df.rename(columns={
    col: f'player2_{col}' for col in player_df.columns if col not in ['tourney_id', 'tourney_date', 'round_code', 'best_of', 'surface_Clay', 'surface_Grass', 'surface_Hard', 'player_id', 'opponent_id','baseline_rally', 'intensity']
})
player2_df = player2_df.rename(columns={'player_id': 'player2_id', 'opponent_id': 'player1_id'})

# 通过 'tourney_id', 'tourney_date', 'player1_id', 'player2_id' 进行合并
match_df = player1_df.merge(player2_df, on=['tourney_id', 'tourney_date', 'round_code', 'best_of', 'surface_Clay', 'surface_Grass', 'surface_Hard', 'player1_id', 'player2_id','baseline_rally', 'intensity'], suffixes=('_p1', '_p2'))

# 取 player1 视角的 result
match_df = match_df.rename(columns={'player1_result': 'result'})
# 删除 player2_result 列，避免冗余
match_df = match_df.drop(columns=['player2_result'])

# 查看结果
print(match_df.head(1))
# Out:
#   tourney_id tourney_date  round_code  best_of  surface_Clay  surface_Grass  \
# 0   2013-414   2013-07-15         2.0        3             1              0
#
#    surface_Hard  player1_id  player2_id  player1_seed_bucket  player1_entry  \
# 0             0      100644      105138                  0.0              0
#
#    player1_host  player1_hand  player1_ht  player1_age  player1_ace  \
# 0             1             1       198.0         16.2          1.0
#
#    player1_df  player1_svpt  player1_fstIn  player1_fstWon  player1_sndWon  \
# 0         7.0          39.0           14.0             7.0             6.0
#
#    player1_SvGms  player1_bpSaved  player1_bpFaced  baseline_rally  intensity  \
# 0            8.0              2.0              8.0        0.705263        1.0
#
#    player1_ace_rate  player1_df_rate  player1_serve_win_rate  \
# 0          0.025641         0.388889                0.333333
#
#    player1_serve_efficiency  player1_clutch_ability  player1_sets  \
# 0                     4.875                0.294118             0
#
#    player1_games  player1_ret  player1_elo_before  player1_elo_after  result  \
# 0              5            0         1600.200888        1600.200888       0
#
#    player1_ace_hist  player1_df_hist  player1_svpt_hist  player1_fstIn_hist  \
# 0               1.0              7.0               39.0                14.0
#
#    player1_fstWon_hist  player1_sndWon_hist  player1_SvGms_hist  \
# 0                  7.0                  6.0                 8.0
#
#    player1_bpSaved_hist  player1_bpFaced_hist  player1_baseline_rally_hist  \
# 0                   2.0                   8.0                     0.705263
#
#    player1_intensity_hist  player1_ace_rate_hist  player1_df_rate_hist  \
# 0                     1.0               0.025641              0.388889
#
#    player1_serve_win_rate_hist  player1_serve_efficiency_hist  \
# 0                     0.333333                          4.875
#
#    player1_clutch_ability_hist  player2_seed_bucket  player2_entry  \
# 0                     0.294118                  0.0              1
#
#    player2_host  player2_hand  player2_ht  player2_age  player2_ace  \
# 0             0             1       183.0         25.2          2.0
#
#    player2_df  player2_svpt  player2_fstIn  player2_fstWon  player2_sndWon  \
# 0         0.0          56.0           42.0            25.0             9.0
#
#    player2_SvGms  player2_bpSaved  player2_bpFaced  player2_ace_rate  \
# 0            9.0              6.0              9.0          0.035714
#
#    player2_df_rate  player2_serve_win_rate  player2_serve_efficiency  \
# 0              0.0                0.607143                  6.222222
#
#    player2_clutch_ability  player2_sets  player2_games  player2_ret  \
# 0                0.705882             2             12            0
#
#    player2_elo_before  player2_elo_after  player2_ace_hist  player2_df_hist  \
# 0          2491.95676         2491.95676          2.357143         2.142857
#
#    player2_svpt_hist  player2_fstIn_hist  player2_fstWon_hist  \
# 0          83.142857           57.047619            36.738095
#
#    player2_sndWon_hist  player2_SvGms_hist  player2_bpSaved_hist  \
# 0            12.666667           12.571429              4.785714
#
#    player2_bpFaced_hist  player2_baseline_rally_hist  player2_intensity_hist  \
# 0              8.428571                     0.707386                0.685638
#
#    player2_ace_rate_hist  player2_df_rate_hist  player2_serve_win_rate_hist  \
# 0               0.028001              0.087961                     0.589462
#
#    player2_serve_efficiency_hist  player2_clutch_ability_hist
# 0                        6.60447                     0.474847

# %%
# 创建一个唯一标识匹配的列，确保 (player1, player2) 和 (player2, player1) 视为相同比赛
match_df['match_key'] = match_df.apply(lambda row: '-'.join(sorted([str(row['player1_id']), str(row['player2_id'])])), axis=1)

# 按照 `tourney_date` 和 `match_key` 进行分组，并随机删除一条重复记录
match_df = match_df.groupby(['tourney_date', 'match_key'], group_keys=False).apply(lambda x: x.sample(1)).reset_index(drop=True)

# 删除临时列 `match_key`
match_df = match_df.drop(columns=['match_key'])

# 查看结果
print(match_df.head(1))
# Out:
#   tourney_id tourney_date  round_code  best_of  surface_Clay  surface_Grass  \
# 0   2000-891   2000-01-03         3.0        3             0              0
#
#    surface_Hard  player1_id  player2_id  player1_seed_bucket  player1_entry  \
# 0             1      104156      101086                  0.0              0
#
#    player1_host  player1_hand  player1_ht  player1_age  player1_ace  \
# 0             1             1   184.35418         16.7          2.0
#
#    player1_df  player1_svpt  player1_fstIn  player1_fstWon  player1_sndWon  \
# 0         3.0          62.0           32.0            22.0            16.0
#
#    player1_SvGms  player1_bpSaved  player1_bpFaced  baseline_rally  intensity  \
# 0           10.0              1.0              4.0        0.650794       0.35
#
#    player1_ace_rate  player1_df_rate  player1_serve_win_rate  \
# 0          0.032258         0.111111                0.612903
#
#    player1_serve_efficiency  player1_clutch_ability  player1_sets  \
# 0                       6.2                0.285714             0
#
#    player1_games  player1_ret  player1_elo_before  player1_elo_after  result  \
# 0              8            0              1509.6             1509.6       0
#
#    player1_ace_hist  player1_df_hist  player1_svpt_hist  player1_fstIn_hist  \
# 0               2.0              3.0               62.0                32.0
#
#    player1_fstWon_hist  player1_sndWon_hist  player1_SvGms_hist  \
# 0                 22.0                 16.0                10.0
#
#    player1_bpSaved_hist  player1_bpFaced_hist  player1_baseline_rally_hist  \
# 0                   1.0                   4.0                     0.650794
#
#    player1_intensity_hist  player1_ace_rate_hist  player1_df_rate_hist  \
# 0                    0.35               0.032258              0.111111
#
#    player1_serve_win_rate_hist  player1_serve_efficiency_hist  \
# 0                     0.612903                            6.2
#
#    player1_clutch_ability_hist  player2_seed_bucket  player2_entry  \
# 0                     0.285714                  6.0              1
#
#    player2_host  player2_hand  player2_ht  player2_age  player2_ace  \
# 0             0             1       180.0         35.1          3.0
#
#    player2_df  player2_svpt  player2_fstIn  player2_fstWon  player2_sndWon  \
# 0         0.0          64.0           35.0            26.0            19.0
#
#    player2_SvGms  player2_bpSaved  player2_bpFaced  player2_ace_rate  \
# 0           10.0              2.0              3.0          0.046875
#
#    player2_df_rate  player2_serve_win_rate  player2_serve_efficiency  \
# 0              0.0                0.703125                       6.4
#
#    player2_clutch_ability  player2_sets  player2_games  player2_ret  \
# 0                0.714286             2             12            0
#
#    player2_elo_before  player2_elo_after  player2_ace_hist  player2_df_hist  \
# 0         1708.548742        1708.548742               3.0              0.0
#
#    player2_svpt_hist  player2_fstIn_hist  player2_fstWon_hist  \
# 0               64.0                35.0                 26.0
#
#    player2_sndWon_hist  player2_SvGms_hist  player2_bpSaved_hist  \
# 0                 19.0                10.0                   2.0
#
#    player2_bpFaced_hist  player2_baseline_rally_hist  player2_intensity_hist  \
# 0                   3.0                     0.650794                    0.35
#
#    player2_ace_rate_hist  player2_df_rate_hist  player2_serve_win_rate_hist  \
# 0               0.046875                   0.0                     0.703125
#
#    player2_serve_efficiency_hist  player2_clutch_ability_hist
# 0                            6.4                     0.714286

# %%
match_df.groupby("result").size()
# Out:
# result
# 0    33100
# 1    32898
# dtype: int64

# %%
match_df.isna().sum()
# Out:
# tourney_id                       0
# tourney_date                     0
# round_code                       0
# best_of                          0
# surface_Clay                     0
# surface_Grass                    0
# surface_Hard                     0
# player1_id                       0
# player2_id                       0
# player1_seed_bucket              0
# player1_entry                    0
# player1_host                     0
# player1_hand                     0
# player1_ht                       0
# player1_age                      0
# player1_ace                      0
# player1_df                       0
# player1_svpt                     0
# player1_fstIn                    0
# player1_fstWon                   0
# player1_sndWon                   0
# player1_SvGms                    0
# player1_bpSaved                  0
# player1_bpFaced                  0
# baseline_rally                   0
# intensity                        0
# player1_ace_rate                 0
# player1_df_rate                  0
# player1_serve_win_rate           0
# player1_serve_efficiency         0
# player1_clutch_ability           0
# player1_sets                     0
# player1_games                    0
# player1_ret                      0
# player1_elo_before               0
# player1_elo_after                0
# result                           0
# player1_ace_hist                 0
# player1_df_hist                  0
# player1_svpt_hist                0
# player1_fstIn_hist               0
# player1_fstWon_hist              0
# player1_sndWon_hist              0
# player1_SvGms_hist               0
# player1_bpSaved_hist             0
# player1_bpFaced_hist             0
# player1_baseline_rally_hist      0
# player1_intensity_hist           0
# player1_ace_rate_hist            0
# player1_df_rate_hist             0
# player1_serve_win_rate_hist      0
# player1_serve_efficiency_hist    0
# player1_clutch_ability_hist      0
# player2_seed_bucket              0
# player2_entry                    0
# player2_host                     0
# player2_hand                     0
# player2_ht                       0
# player2_age                      0
# player2_ace                      0
# player2_df                       0
# player2_svpt                     0
# player2_fstIn                    0
# player2_fstWon                   0
# player2_sndWon                   0
# player2_SvGms                    0
# player2_bpSaved                  0
# player2_bpFaced                  0
# player2_ace_rate                 0
# player2_df_rate                  0
# player2_serve_win_rate           0
# player2_serve_efficiency         0
# player2_clutch_ability           0
# player2_sets                     0
# player2_games                    0
# player2_ret                      0
# player2_elo_before               0
# player2_elo_after                0
# player2_ace_hist                 0
# player2_df_hist                  0
# player2_svpt_hist                0
# player2_fstIn_hist               0
# player2_fstWon_hist              0
# player2_sndWon_hist              0
# player2_SvGms_hist               0
# player2_bpSaved_hist             0
# player2_bpFaced_hist             0
# player2_baseline_rally_hist      0
# player2_intensity_hist           0
# player2_ace_rate_hist            0
# player2_df_rate_hist             0
# player2_serve_win_rate_hist      0
# player2_serve_efficiency_hist    0
# player2_clutch_ability_hist      0
# dtype: int64

# %%
# 确保 tourney_date 是 datetime 类型
match_df['tourney_date'] = pd.to_datetime(match_df['tourney_date'])

# 根据年份范围划分数据
match_df_00_04 = match_df[(match_df['tourney_date'].dt.year >= 2000) & (match_df['tourney_date'].dt.year <= 2004)]
match_df_05_09 = match_df[(match_df['tourney_date'].dt.year >= 2005) & (match_df['tourney_date'].dt.year <= 2009)]
match_df_10_14 = match_df[(match_df['tourney_date'].dt.year >= 2010) & (match_df['tourney_date'].dt.year <= 2014)]
match_df_15_19 = match_df[(match_df['tourney_date'].dt.year >= 2015) & (match_df['tourney_date'].dt.year <= 2019)]
match_df_20_24 = match_df[(match_df['tourney_date'].dt.year >= 2020) & (match_df['tourney_date'].dt.year <= 2024)]

# %%
dfs = {
    "match_df_00_04": match_df_00_04,
    "match_df_05_09": match_df_05_09,
    "match_df_10_14": match_df_10_14,
    "match_df_15_19": match_df_15_19,
    "match_df_20_24": match_df_20_24
}

output_directory = os.path.join("..", "dataset", "processed_data")
os.makedirs(output_directory, exist_ok=True)  # 创建目录（如果不存在）
for key, df in dfs.items():
    print(f"{key}: {len(df)} rows")
    output_file = os.path.join(output_directory, f"{key}.csv")
    df.to_csv(output_file, index=False, encoding="utf-8-sig")
    print(f"已保存: {output_file}")
# Out:
# match_df_00_04: 13970 rows
# 已保存: F:\大四\tennis_predicton\processed_data\match_df_00_04.csv
# match_df_05_09: 13616 rows
# 已保存: F:\大四\tennis_predicton\processed_data\match_df_05_09.csv
# match_df_10_14: 12770 rows
# 已保存: F:\大四\tennis_predicton\processed_data\match_df_10_14.csv
# match_df_15_19: 13414 rows
# 已保存: F:\大四\tennis_predicton\processed_data\match_df_15_19.csv
# match_df_20_24: 12228 rows
# 已保存: F:\大四\tennis_predicton\processed_data\match_df_20_24.csv

# %%
match_df.to_csv(r"..\processed_data\match_expanded.csv", index=False, encoding="utf-8-sig")

# %%
match_df.columns
# Out:
# Index(['tourney_id', 'tourney_date', 'round_code', 'best_of', 'surface_Clay',
#        'surface_Grass', 'surface_Hard', 'player1_id', 'player2_id',
#        'player1_seed_bucket', 'player1_entry', 'player1_host', 'player1_hand',
#        'player1_ht', 'player1_age', 'player1_ace', 'player1_df',
#        'player1_svpt', 'player1_fstIn', 'player1_fstWon', 'player1_sndWon',
#        'player1_SvGms', 'player1_bpSaved', 'player1_bpFaced', 'baseline_rally',
#        'intensity', 'player1_ace_rate', 'player1_df_rate',
#        'player1_serve_win_rate', 'player1_serve_efficiency',
#        'player1_clutch_ability', 'player1_sets', 'player1_games',
#        'player1_ret', 'player1_elo_before', 'player1_elo_after', 'result',
#        'player1_ace_hist', 'player1_df_hist', 'player1_svpt_hist',
#        'player1_fstIn_hist', 'player1_fstWon_hist', 'player1_sndWon_hist',
#        'player1_SvGms_hist', 'player1_bpSaved_hist', 'player1_bpFaced_hist',
#        'player1_baseline_rally_hist', 'player1_intensity_hist',
#        'player1_ace_rate_hist', 'player1_df_rate_hist',
#        'player1_serve_win_rate_hist', 'player1_serve_efficiency_hist',
#        'player1_clutch_ability_hist', 'player2_seed_bucket', 'player2_entry',
#        'player2_host', 'player2_hand', 'player2_ht', 'player2_age',
#        'player2_ace', 'player2_df', 'player2_svpt', 'player2_fstIn',
#        'player2_fstWon', 'player2_sndWon', 'player2_SvGms', 'player2_bpSaved',
#        'player2_bpFaced', 'player2_ace_rate', 'player2_df_rate',
#        'player2_serve_win_rate', 'player2_serve_efficiency',
#        'player2_clutch_ability', 'player2_sets', 'player2_games',
#        'player2_ret', 'player2_elo_before', 'player2_elo_after',
#        'player2_ace_hist', 'player2_df_hist', 'player2_svpt_hist',
#        'player2_fstIn_hist', 'player2_fstWon_hist', 'player2_sndWon_hist',
#        'player2_SvGms_hist', 'player2_bpSaved_hist', 'player2_bpFaced_hist',
#        'player2_baseline_rally_hist', 'player2_intensity_hist',
#        'player2_ace_rate_hist', 'player2_df_rate_hist',
#        'player2_serve_win_rate_hist', 'player2_serve_efficiency_hist',
#        'player2_clutch_ability_hist'],
#       dtype='object')
